# %% [markdown]
# # Analysis of Foursquare Model Weight
# # NYU - CUSP UDP Capstone
# # Foursquare + NYC Merge by CT
# ## Brief
# This notebook
# 1. Part I. Data Processing
#     - import Models Weight
#     - Plot top 10 most important weights for every model
#
# ###  You can refer to https://github.com/mv1742/updny_2

# %% [markdown]
# # Part I. Data Processing

# %%
import os
import requests
import shapely
import json

import matplotlib.pyplot as plt #plotting
import pandas as pd
import numpy as np
import scipy.stats as stat
#make sure plots are embedded into the notebook
# %matplotlib inline
#import statsmodels.formula.api as smf
import itertools
import geopandas as gpd
from shapely.geometry import Point, Polygon
from sklearn.metrics import silhouette_score
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import geopandas as gpd
import pylab as pl
import io
import pylab as pl

from geopandas import GeoDataFrame
from geopandas.tools import sjoin
try:
    import ipywidgets as widgets
    hasWidgets = True
except ImportError:
    hasWidgets = False
from sklearn.linear_model import LogisticRegression
from sklearn import svm
# from sklearn.metrics import confusion_matrix
# from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
# from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report
import matplotlib.pylab
import sklearn.preprocessing as preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['Polygon', 'linalg']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
weights_results = ['gent00_16.csv','Ongoing_adv_gent.csv',\
'pct_ch_hinc00_16.csv','pct_ch_medhval00_16.csv',\
'pct_ch_percol00_16.csv',
'Supergent16.csv']
weights_results
# Out:
# ['gent00_16.csv',
#  'Ongoing_adv_gent.csv',
#  'pct_ch_hinc00_16.csv',
#  'pct_ch_medhval00_16.csv',
#  'pct_ch_percol00_16.csv',
#  'Supergent16.csv']

# %%
weights_df_list = []
for file in weights_results:
    print(file)
    temp = pd.read_csv('./Results/'+file)
    temp.rename(columns={'Unnamed: 0':'St_method'}, inplace=True)
    weights_df_list.append(temp)
# Out:
# gent00_16.csv
# Ongoing_adv_gent.csv
# pct_ch_hinc00_16.csv
# pct_ch_medhval00_16.csv
# pct_ch_percol00_16.csv
# Supergent16.csv

# %%
binary_typs = []
for w in weights_results:
    print(w)
    binary_typs.append(w[:-4])
binary_typs
# Out:
# gent00_16.csv
# Ongoing_adv_gent.csv
# pct_ch_hinc00_16.csv
# pct_ch_medhval00_16.csv
# pct_ch_percol00_16.csv
# Supergent16.csv
# ['gent00_16',
#  'Ongoing_adv_gent',
#  'pct_ch_hinc00_16',
#  'pct_ch_medhval00_16',
#  'pct_ch_percol00_16',
#  'Supergent16']

# %%
weights_df[0].loc[0][1:].abs().sort_values(ascending=False)[:10].index[::-1]
# Out:
# Index(['Category_Nutrition_sum10', 'Category_Consumption_sum10', 'Users',
#        'Class__sum10', 'Category_Unknown_sum10', 'Checkins',
#        'Class_Necessary_sum10', 'Visits', 'Class_Optional_sum10',
#        'Rating_sum10'],
#       dtype='object')

# %%
top10_pd = pd.DataFrame()
for i, binary_target in enumerate(binary_typs):
    print(i, binary_target)
    for st_method in list(weights_df_list[i].index):
        print('st_method',st_method)
        pd_series_by_st_method = weights_df_list[i].loc[st_method]
        for k, variable in enumerate(pd_series_by_st_method[1:].abs().sort_values(ascending=False)[:10].index[::-1]):
            print(k,variable)
            top10_pd.loc[st_method,variable] = k
top10_pd
# Out:
# 0 gent00_16
# st_method 0
# 0 Category_Nutrition_sum10
# 1 Category_Consumption_sum10
# 2 Users
# 3 Class__sum10
# 4 Category_Unknown_sum10
# 5 Checkins
# 6 Class_Necessary_sum10
# 7 Visits
# 8 Class_Optional_sum10
# 9 Rating_sum10
# st_method 1
# 0 Type_Private School_sum10
# 1 Type_Drugstore_sum10
# 2 Type_Knitting Store_sum10
# 3 Type_Forest_sum10
# 4 Users_sum10
# 5 Type_States & Municipalities_sum10
# 6 Type_Bus Station
# 7 Type_Wedding Hall_sum10
# 8 distance_to_Type_Cocktail Bar
# 9 distance_to_Type_Bar
# st_method 2
# 0 Type_Private School_sum10
# 1 Type_Drugstore_sum10
# 2 Type_Forest_sum10
# 3 Users_sum10
# 4 Type_Emergency Room_sum10
# 5 distance_to_Type_Cocktail Bar
# 6 Type_Steakhouse
# 7 Type_Bus Station
# 8 Type_Wedding Hall_sum10
# 9 distance_to_Type_Bar
# st_method 3
# 0 Type_Car Wash
# 1 Type_Butcher
# 2 Type_Department Store
# 3 Type_Bowling Alley
# 4 Type_Garden
# 5 Type_Russian Restaurant
# 6 Type_Automotive Shop
# 7 Type_Road
# 8 Type_Residential Building (Apartment / Condo)
# 9 Type_Bubble Tea Shop
# st_method 4
# 0 Type_Department Store
# 1 Type_Bubble Tea Shop
# 2 Type_Building
# 3 Type_Automotive Shop
# 4 distance_to_Type_Spanish Restaurant
# 5 distance_to_Type_Steakhouse
# 6 Type_Road
# 7 distance_to_Category_Income
# 8 distance_to_Type_Bar
# 9 distance_to_Class_Optional
# st_method 5
# 0 Type_Kitchen Supply Store_sum10
# 1 Type_Private School_sum10
# 2 Type_Drugstore_sum10
# 3 Type_Forest_sum10
# 4 Type_Dentist's Office
# 5 distance_to_Type_Cocktail Bar
# 6 Type_Steakhouse
# 7 Type_Bus Station
# 8 Type_Ski Lodge_sum10
# 9 distance_to_Type_Bar
# st_method 6
# 0 Type_Private School_sum10
# 1 Type_Drugstore_sum10
# 2 Type_Forest_sum10
# 3 Users_sum10
# 4 Type_Emergency Room_sum10
# 5 distance_to_Type_Cocktail Bar
# 6 Type_Steakhouse
# 7 Type_Bus Station
# 8 Type_Wedding Hall_sum10
# 9 distance_to_Type_Bar
# st_method 7
# 0 Type_Car Wash
# 1 Type_Butcher
# 2 Type_Department Store
# 3 Type_Bowling Alley
# 4 Type_Garden
# 5 Type_Russian Restaurant
# 6 Type_Automotive Shop
# 7 Type_Road
# 8 Type_Residential Building (Apartment / Condo)
# 9 Type_Bubble Tea Shop
# st_method 8
# 0 Type_Car Wash
# 1 Type_Butcher
# 2 Type_Department Store
# 3 Type_Bowling Alley
# 4 Type_Garden
# 5 Type_Russian Restaurant
# 6 Type_Automotive Shop
# 7 Type_Road
# 8 Type_Residential Building (Apartment / Condo)
# 9 Type_Bubble Tea Shop
# st_method 9
# 0 Type_Private School_sum10
# 1 Type_Drugstore_sum10
# 2 Type_Forest_sum10
# 3 Users_sum10
# 4 Type_Emergency Room_sum10
# 5 distance_to_Type_Cocktail Bar
# 6 Type_Steakhouse
# 7 Type_Bus Station
# 8 Type_Wedding Hall_sum10
# 9 distance_to_Type_Bar
# st_method 10
# 0 Type_Private School_sum10
# 1 Type_Drugstore_sum10
# 2 Type_Forest_sum10
# 3 Users_sum10
# 4 Type_Emergency Room_sum10
# 5 distance_to_Type_Cocktail Bar
# 6 Type_Steakhouse
# 7 Type_Bus Station
# 8 Type_Wedding Hall_sum10
# 9 distance_to_Type_Bar
# st_method 11
# 0 Type_Car Wash
# 1 Type_Butcher
# 2 Type_Department Store
# 3 Type_Bowling Alley
# 4 Type_Garden
# 5 Type_Russian Restaurant
# 6 Type_Automotive Shop
# 7 Type_Road
# 8 Type_Residential Building (Apartment / Condo)
# 9 Type_Bubble Tea Shop
# 1 Ongoing_adv_gent
# st_method 0
# 0 Category_Civic_sum10
# 1 Visits
# 2 Category_Nutrition_sum10
# 3 Class__sum10
# 4 Category_Unknown_sum10
# 5 Category_Consumption_sum10
# 6 Category_Social_sum10
# 7 Class_Necessary_sum10
# 8 Rating_sum10
# 9 Class_Optional_sum10
# st_method 1
# 0 Type_Leather Goods Store_sum10
# 1 Type_Memorial Site_sum10
# 2 Type_Boat Rental_sum10
# 3 Type_Electronics Store_sum10
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 2
# 0 Type_Leather Goods Store_sum10
# 1 Type_Adult Education Center_sum10
# 2 Type_Residential Building (Apartment / Condo)_sum10
# 3 distance_to_Category_Education
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 3
# 0 Type_Clothing Store
# 1 Type_Cave
# 2 Type_Event Space
# 3 Type_Hockey Arena
# 4 Type_Frozen Yogurt Shop_sum10
# 5 Type_Monument / Landmark
# 6 Type_Furniture / Home Store
# 7 Type_Men's Store
# 8 Type_Parking
# 9 Type_Tech Startup
# st_method 4
# 0 distance_to_Type_Steakhouse
# 1 Type_Frozen Yogurt Shop_sum10
# 2 Type_Japanese Restaurant
# 3 distance_to_Type_Juice Bar
# 4 Type_Furniture / Home Store
# 5 Type_Roof Deck
# 6 Type_Monument / Landmark
# 7 Type_Men's Store
# 8 distance_to_Class_
# 9 Type_Tech Startup
# st_method 5
# 0 Type_Memorial Site_sum10
# 1 Class_Necessary
# 2 Type_Residential Building (Apartment / Condo)_sum10
# 3 Type_Check Cashing Service_sum10
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 6
# 0 Type_Leather Goods Store_sum10
# 1 Type_Adult Education Center_sum10
# 2 Type_Residential Building (Apartment / Condo)_sum10
# 3 distance_to_Category_Education
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 7
# 0 Type_Clothing Store
# 1 Type_Cave
# 2 Type_Event Space
# 3 Type_Hockey Arena
# 4 Type_Frozen Yogurt Shop_sum10
# 5 Type_Monument / Landmark
# 6 Type_Furniture / Home Store
# 7 Type_Men's Store
# 8 Type_Parking
# 9 Type_Tech Startup
# st_method 8
# 0 Type_Clothing Store
# 1 Type_Cave
# 2 Type_Event Space
# 3 Type_Hockey Arena
# 4 Type_Frozen Yogurt Shop_sum10
# 5 Type_Monument / Landmark
# 6 Type_Furniture / Home Store
# 7 Type_Men's Store
# 8 Type_Parking
# 9 Type_Tech Startup
# st_method 9
# 0 Type_Leather Goods Store_sum10
# 1 Type_Adult Education Center_sum10
# 2 Type_Residential Building (Apartment / Condo)_sum10
# 3 distance_to_Category_Education
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 10
# 0 Type_Leather Goods Store_sum10
# 1 Type_Adult Education Center_sum10
# 2 Type_Residential Building (Apartment / Condo)_sum10
# 3 distance_to_Category_Education
# 4 distance_to_Type_New American Restaurant
# 5 Type_Farmers Market_sum10
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Track Stadium_sum10
# 8 Type_Pub_sum10
# 9 Type_Industrial Estate_sum10
# st_method 11
# 0 Type_Clothing Store
# 1 Type_Cave
# 2 Type_Event Space
# 3 Type_Hockey Arena
# 4 Type_Frozen Yogurt Shop_sum10
# 5 Type_Monument / Landmark
# 6 Type_Furniture / Home Store
# 7 Type_Men's Store
# 8 Type_Parking
# 9 Type_Tech Startup
# 2 pct_ch_hinc00_16
# st_method 0
# 0 Type_Plane_sum10
# 1 Category_Taking care_sum10
# 2 Category_Mobility_sum10
# 3 Category_Civic_sum10
# 4 Category_Nutrition_sum10
# 5 Type_Residential Building (Apartment / Condo)_sum10
# 6 Category_Social_sum10
# 7 Rating_sum10
# 8 Class_Optional_sum10
# 9 Class_Necessary_sum10
# st_method 1
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 2
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 3
# 0 Type_Taxi
# 1 Type_Platform
# 2 distance_to_Type_Gastropub
# 3 Type_Tour Provider
# 4 Type_Gym
# 5 Type_Athletics & Sports
# 6 Type_Hotel
# 7 Type_City Hall
# 8 Type_Hot Dog Joint
# 9 Rating
# st_method 4
# 0 distance_to_Type_Steakhouse
# 1 Type_Taxi
# 2 Type_Gym
# 3 Type_Hockey Arena_sum10
# 4 distance_to_Category_Unknown
# 5 distance_to_Category_Personal care
# 6 Type_Hot Dog Joint
# 7 distance_to_Type_Gastropub
# 8 Type_Art Gallery
# 9 Rating
# st_method 5
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 6
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 7
# 0 Type_Taxi
# 1 Type_Platform
# 2 distance_to_Type_Gastropub
# 3 Type_Tour Provider
# 4 Type_Gym
# 5 Type_Athletics & Sports
# 6 Type_Hotel
# 7 Type_City Hall
# 8 Type_Hot Dog Joint
# 9 Rating
# st_method 8
# 0 Type_Taxi
# 1 Type_Platform
# 2 distance_to_Type_Gastropub
# 3 Type_Tour Provider
# 4 Type_Gym
# 5 Type_Athletics & Sports
# 6 Type_Hotel
# 7 Type_City Hall
# 8 Type_Hot Dog Joint
# 9 Rating
# st_method 9
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 10
# 0 Type_Other Great Outdoors
# 1 Type_Nail Salon
# 2 Type_Miscellaneous Shop
# 3 Type_Pharmacy
# 4 distance_to_Type_Salad Place
# 5 Type_Festival_sum10
# 6 distance_to_Type_Gastropub
# 7 Type_Multiplex_sum10
# 8 distance_to_Type_Beer Garden
# 9 Type_Tour Provider_sum10
# st_method 11
# 0 Type_Taxi
# 1 Type_Platform
# 2 distance_to_Type_Gastropub
# 3 Type_Tour Provider
# 4 Type_Gym
# 5 Type_Athletics & Sports
# 6 Type_Hotel
# 7 Type_City Hall
# 8 Type_Hot Dog Joint
# 9 Rating
# 3 pct_ch_medhval00_16
# st_method 0
# 0 Category_Personal care_sum10
# 1 Category_Mobility_sum10
# 2 Category_Civic_sum10
# 3 Category_Taking care_sum10
# 4 Category_Nutrition_sum10
# 5 Category_Consumption_sum10
# 6 Category_Social_sum10
# 7 Rating_sum10
# 8 Class_Necessary_sum10
# 9 Class_Optional_sum10
# st_method 1
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 2
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 3
# 0 Type_Lawyer
# 1 distance_to_Type_French Restaurant
# 2 Type_General Travel
# 3 Type_Conference Room
# 4 Type_Zoo Exhibit
# 5 Type_Building
# 6 Type_Coffee Shop
# 7 distance_to_Category_Nutrition
# 8 Type_Furniture / Home Store
# 9 distance_to_Type_American Restaurant
# st_method 4
# 0 Type_College Arts Building
# 1 Type_Financial or Legal Service
# 2 distance_to_Category_Nutrition
# 3 Type_General Travel
# 4 Type_Building
# 5 distance_to_Category_Unknown
# 6 distance_to_Type_Caribbean Restaurant
# 7 Type_Furniture / Home Store
# 8 Type_Coffee Shop
# 9 distance_to_Type_American Restaurant
# st_method 5
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 6
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 7
# 0 Type_Lawyer
# 1 distance_to_Type_French Restaurant
# 2 Type_General Travel
# 3 Type_Conference Room
# 4 Type_Zoo Exhibit
# 5 Type_Building
# 6 Type_Coffee Shop
# 7 distance_to_Category_Nutrition
# 8 Type_Furniture / Home Store
# 9 distance_to_Type_American Restaurant
# st_method 8
# 0 Type_Lawyer
# 1 distance_to_Type_French Restaurant
# 2 Type_General Travel
# 3 Type_Conference Room
# 4 Type_Zoo Exhibit
# 5 Type_Building
# 6 Type_Coffee Shop
# 7 distance_to_Category_Nutrition
# 8 Type_Furniture / Home Store
# 9 distance_to_Type_American Restaurant
# st_method 9
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 10
# 0 Type_Bus Line
# 1 Type_School
# 2 Type_Gas Station
# 3 distance_to_Users
# 4 Rating
# 5 Type_Music Festival_sum10
# 6 Type_Ski Chalet_sum10
# 7 Type_Multiplex_sum10
# 8 distance_to_Category_Nutrition
# 9 Type_Tour Provider_sum10
# st_method 11
# 0 Type_Lawyer
# 1 distance_to_Type_French Restaurant
# 2 Type_General Travel
# 3 Type_Conference Room
# 4 Type_Zoo Exhibit
# 5 Type_Building
# 6 Type_Coffee Shop
# 7 distance_to_Category_Nutrition
# 8 Type_Furniture / Home Store
# 9 distance_to_Type_American Restaurant
# 4 pct_ch_percol00_16
# st_method 0
# 0 Category_Mobility_sum10
# 1 Category_Civic_sum10
# 2 Category_Nutrition_sum10
# 3 Visits
# 4 Category_Consumption_sum10
# 5 Category_Social_sum10
# 6 Type_Residential Building (Apartment / Condo)_sum10
# 7 Rating_sum10
# 8 Class_Necessary_sum10
# 9 Class_Optional_sum10
# st_method 1
# 0 Category_Income
# 1 Type_Hunan Restaurant_sum10
# 2 Category_Nutrition
# 3 Type_History Museum_sum10
# 4 Type_College Library
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 2
# 0 Category_Income
# 1 Type_Hunan Restaurant_sum10
# 2 Type_Golf Driving Range_sum10
# 3 Type_Warehouse Store_sum10
# 4 distance_to_Type_Latin American Restaurant
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 3
# 0 Type_Prayer Room_sum10
# 1 Type_Travel Agency
# 2 Type_College Administrative Building
# 3 Type_Art Museum
# 4 Type_Fujian Restaurant_sum10
# 5 distance_to_Class_
# 6 Type_Transportation Service
# 7 distance_to_Category_Nutrition
# 8 Type_Shoe Store
# 9 Type_Asian Restaurant
# st_method 4
# 0 Type_Prayer Room_sum10
# 1 Type_Turkish Restaurant
# 2 Type_Scenic Lookout
# 3 distance_to_Category_Taking care
# 4 Type_Transportation Service
# 5 distance_to_Class_
# 6 distance_to_Category_Nutrition
# 7 Type_Fujian Restaurant_sum10
# 8 Type_Shoe Store
# 9 Type_Asian Restaurant
# st_method 5
# 0 Type_Hunan Restaurant_sum10
# 1 Category_Nutrition
# 2 Type_Burrito Place_sum10
# 3 Type_Art Museum_sum10
# 4 Type_Bowling Alley_sum10
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 6
# 0 Category_Income
# 1 Type_Hunan Restaurant_sum10
# 2 Type_Golf Driving Range_sum10
# 3 Type_Warehouse Store_sum10
# 4 distance_to_Type_Latin American Restaurant
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 7
# 0 Type_Prayer Room_sum10
# 1 Type_Travel Agency
# 2 Type_College Administrative Building
# 3 Type_Art Museum
# 4 Type_Fujian Restaurant_sum10
# 5 distance_to_Class_
# 6 Type_Transportation Service
# 7 distance_to_Category_Nutrition
# 8 Type_Shoe Store
# 9 Type_Asian Restaurant
# st_method 8
# 0 Type_Prayer Room_sum10
# 1 Type_Travel Agency
# 2 Type_College Administrative Building
# 3 Type_Art Museum
# 4 Type_Fujian Restaurant_sum10
# 5 distance_to_Class_
# 6 Type_Transportation Service
# 7 distance_to_Category_Nutrition
# 8 Type_Shoe Store
# 9 Type_Asian Restaurant
# st_method 9
# 0 Category_Income
# 1 Type_Hunan Restaurant_sum10
# 2 Type_Golf Driving Range_sum10
# 3 Type_Warehouse Store_sum10
# 4 distance_to_Type_Latin American Restaurant
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 10
# 0 Category_Income
# 1 Type_Hunan Restaurant_sum10
# 2 Type_Golf Driving Range_sum10
# 3 Type_Warehouse Store_sum10
# 4 distance_to_Type_Latin American Restaurant
# 5 Type_TV Station_sum10
# 6 distance_to_Category_Unknown
# 7 Type_Fondue Restaurant_sum10
# 8 Type_Dim Sum Restaurant_sum10
# 9 Type_Confucian Temple_sum10
# st_method 11
# 0 Type_Prayer Room_sum10
# 1 Type_Travel Agency
# 2 Type_College Administrative Building
# 3 Type_Art Museum
# 4 Type_Fujian Restaurant_sum10
# 5 distance_to_Class_
# 6 Type_Transportation Service
# 7 distance_to_Category_Nutrition
# 8 Type_Shoe Store
# 9 Type_Asian Restaurant
# 5 Supergent16
# st_method 0
# 0 Class__sum10
# 1 Category_Unknown_sum10
# 2 Category_Nutrition_sum10
# 3 Category_Consumption_sum10
# 4 Category_Personal care_sum10
# 5 Class_Necessary_sum10
# 6 Rating_sum10
# 7 Users
# 8 Checkins
# 9 Visits
# st_method 1
# 0 Type_Night Market_sum10
# 1 Type_Playground
# 2 Type_Ice Cream Shop
# 3 Rating_sum10
# 4 distance_to_Category_Personal care
# 5 distance_to_Class_Necessary
# 6 Type_Accessories Store
# 7 distance_to_Category_Consumption
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 2
# 0 Type_Arts & Entertainment_sum10
# 1 Type_Bus Station
# 2 Type_Coworking Space
# 3 Rating_sum10
# 4 Type_Cafeteria
# 5 distance_to_Category_Income
# 6 Type_Accessories Store
# 7 Class_Optional
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 3
# 0 distance_to_Category_Nutrition
# 1 distance_to_Type_Café
# 2 Type_Travel Agency
# 3 distance_to_Type_Latin American Restaurant
# 4 Type_Tailor Shop
# 5 Type_Museum
# 6 distance_to_Category_Social
# 7 Type_Buffet
# 8 Type_City
# 9 Type_Storage Facility
# st_method 4
# 0 distance_to_Type_Bar
# 1 distance_to_Type_Café
# 2 Type_Buffet
# 3 distance_to_Category_Nutrition
# 4 Type_Modern European Restaurant_sum10
# 5 distance_to_Category_Social
# 6 Type_City
# 7 distance_to_Type_Latin American Restaurant
# 8 Type_Museum
# 9 Type_Storage Facility
# st_method 5
# 0 Type_Bus Station
# 1 Type_Night Market_sum10
# 2 Type_Playground
# 3 Rating_sum10
# 4 distance_to_Type_American Restaurant
# 5 Type_Cafeteria
# 6 Type_Accessories Store
# 7 Type_Italian Restaurant
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 6
# 0 Type_Arts & Entertainment_sum10
# 1 Type_Bus Station
# 2 Type_Coworking Space
# 3 Rating_sum10
# 4 Type_Cafeteria
# 5 distance_to_Category_Income
# 6 Type_Accessories Store
# 7 Class_Optional
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 7
# 0 distance_to_Category_Nutrition
# 1 distance_to_Type_Café
# 2 Type_Travel Agency
# 3 distance_to_Type_Latin American Restaurant
# 4 Type_Tailor Shop
# 5 Type_Museum
# 6 distance_to_Category_Social
# 7 Type_Buffet
# 8 Type_City
# 9 Type_Storage Facility
# st_method 8
# 0 distance_to_Category_Nutrition
# 1 distance_to_Type_Café
# 2 Type_Travel Agency
# 3 distance_to_Type_Latin American Restaurant
# 4 Type_Tailor Shop
# 5 Type_Museum
# 6 distance_to_Category_Social
# 7 Type_Buffet
# 8 Type_City
# 9 Type_Storage Facility
# st_method 9
# 0 Type_Arts & Entertainment_sum10
# 1 Type_Bus Station
# 2 Type_Coworking Space
# 3 Rating_sum10
# 4 Type_Cafeteria
# 5 distance_to_Category_Income
# 6 Type_Accessories Store
# 7 Class_Optional
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 10
# 0 Type_Arts & Entertainment_sum10
# 1 Type_Bus Station
# 2 Type_Coworking Space
# 3 Rating_sum10
# 4 Type_Cafeteria
# 5 distance_to_Category_Income
# 6 Type_Accessories Store
# 7 Class_Optional
# 8 distance_to_Type_Latin American Restaurant
# 9 distance_to_Type_French Restaurant
# st_method 11
# 0 distance_to_Category_Nutrition
# 1 distance_to_Type_Café
# 2 Type_Travel Agency
# 3 distance_to_Type_Latin American Restaurant
# 4 Type_Tailor Shop
# 5 Type_Museum
# 6 distance_to_Category_Social
# 7 Type_Buffet
# 8 Type_City
# 9 Type_Storage Facility
#     Category_Nutrition_sum10  Category_Consumption_sum10  Users  Class__sum10  \
# 0                        2.0                         3.0    7.0           0.0
# 1                        NaN                         NaN    NaN           NaN
# 2                        NaN                         NaN    NaN           NaN
# 3                        NaN                         NaN    NaN           NaN
# 4                        NaN                         NaN    NaN           NaN
# 5                        NaN                         NaN    NaN           NaN
# 6                        NaN                         NaN    NaN           NaN
# 7                        NaN                         NaN    NaN           NaN
# 8                        NaN                         NaN    NaN           NaN
# 9                        NaN                         NaN    NaN           NaN
# 10                       NaN                         NaN    NaN           NaN
# 11                       NaN                         NaN    NaN           NaN
#
#     Category_Unknown_sum10  Checkins  Class_Necessary_sum10  Visits  \
# 0                      1.0       8.0                    5.0     9.0
# 1                      NaN       NaN                    NaN     NaN
# 2                      NaN       NaN                    NaN     NaN
# 3                      NaN       NaN                    NaN     NaN
# 4                      NaN       NaN                    NaN     NaN
# 5                      NaN       NaN                    NaN     NaN
# 6                      NaN       NaN                    NaN     NaN
# 7                      NaN       NaN                    NaN     NaN
# 8                      NaN       NaN                    NaN     NaN
# 9                      NaN       NaN                    NaN     NaN
# 10                     NaN       NaN                    NaN     NaN
# 11                     NaN       NaN                    NaN     NaN
#
#     Class_Optional_sum10  Rating_sum10           ...             \
# 0                    9.0           6.0           ...
# 1                    NaN           3.0           ...
# 2                    NaN           3.0           ...
# 3                    NaN           NaN           ...
# 4                    NaN           NaN           ...
# 5                    NaN           3.0           ...
# 6                    NaN           3.0           ...
# 7                    NaN           NaN           ...
# 8                    NaN           NaN           ...
# 9                    NaN           3.0           ...
# 10                   NaN           3.0           ...
# 11                   NaN           NaN           ...
#
#     Class_Optional  distance_to_Type_Café  Type_Tailor Shop  Type_Museum  \
# 0              NaN                    NaN               NaN          NaN
# 1              NaN                    NaN               NaN          NaN
# 2              7.0                    NaN               NaN          NaN
# 3              NaN                    1.0               4.0          5.0
# 4              NaN                    1.0               NaN          8.0
# 5              NaN                    NaN               NaN          NaN
# 6              7.0                    NaN               NaN          NaN
# 7              NaN                    1.0               4.0          5.0
# 8              NaN                    1.0               4.0          5.0
# 9              7.0                    NaN               NaN          NaN
# 10             7.0                    NaN               NaN          NaN
# 11             NaN                    1.0               4.0          5.0
#
#     distance_to_Category_Social  Type_Buffet  Type_City  \
# 0                           NaN          NaN        NaN
# 1                           NaN          NaN        NaN
# 2                           NaN          NaN        NaN
# 3                           6.0          7.0        8.0
# 4                           5.0          2.0        6.0
# 5                           NaN          NaN        NaN
# 6                           NaN          NaN        NaN
# 7                           6.0          7.0        8.0
# 8                           6.0          7.0        8.0
# 9                           NaN          NaN        NaN
# 10                          NaN          NaN        NaN
# 11                          6.0          7.0        8.0
#
#     Type_Storage Facility  Type_Modern European Restaurant_sum10  \
# 0                     NaN                                    NaN
# 1                     NaN                                    NaN
# 2                     NaN                                    NaN
# 3                     9.0                                    NaN
# 4                     9.0                                    4.0
# 5                     NaN                                    NaN
# 6                     NaN                                    NaN
# 7                     9.0                                    NaN
# 8                     9.0                                    NaN
# 9                     NaN                                    NaN
# 10                    NaN                                    NaN
# 11                    9.0                                    NaN
#
#     Type_Italian Restaurant
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       7.0
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
#
# [12 rows x 159 columns]

# %%
print(weights_results[3])
st_method = 8
print(st_method, (weights_df_list[3].loc[st_method][0]))
weights_df_list[3].loc[st_method][1:].abs().sort_values(ascending=False)[:10].index[::-1]
# Out:
# pct_ch_medhval00_16.csv
# 8 Logit_Minmaxed
# Index(['Type_Lawyer', 'distance_to_Type_French Restaurant',
#        'Type_General Travel', 'Type_Conference Room', 'Type_Zoo Exhibit',
#        'Type_Building', 'Type_Coffee Shop', 'distance_to_Category_Nutrition',
#        'Type_Furniture / Home Store', 'distance_to_Type_American Restaurant'],
#       dtype='object')

# %%
top10_pd.sum(axis=0).sort_values(ascending=False)[:10]
# Out:
# Rating                                        69.0
# distance_to_Type_Latin American Restaurant    67.0
# distance_to_Type_French Restaurant            58.0
# distance_to_Type_Bar                          54.0
# Type_Confucian Temple_sum10                   54.0
# Type_Tour Provider_sum10                      54.0
# Type_Industrial Estate_sum10                  54.0
# distance_to_Type_Gastropub                    51.0
# distance_to_Category_Nutrition                51.0
# distance_to_Type_American Restaurant          49.0
# dtype: float64

# %%
# top10_pd = pd.DataFrame():
# for binary_variable in binary_variables:
#     top10_pd[binary_variable] = weights_df[0].loc[0][1:].abs().sort_values(ascending=False)[:10].index
# Out:
# Index(['Rating_sum10', 'Class_Optional_sum10', 'Visits',
#        'Class_Necessary_sum10', 'Checkins', 'Category_Unknown_sum10',
#        'Class__sum10', 'Users', 'Category_Consumption_sum10',
#        'Category_Nutrition_sum10'],
#       dtype='object')
