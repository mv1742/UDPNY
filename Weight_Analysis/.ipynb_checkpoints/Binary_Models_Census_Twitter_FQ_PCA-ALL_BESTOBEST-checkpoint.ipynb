# %% [markdown]
# # Analysis of Foursquare Model Weight
# # NYU - CUSP UDP Capstone
# # Foursquare + TWITTER + CENSUS NYC Merge by CT
# ## Brief
# This notebook
# 1. Part I. Data Processing
#     - import Models Weight
#     - Plot top 10 most important weights for every model
#
# ###  You can refer to https://github.com/mv1742/updny_2

# %% [markdown]
# # Part I. Data Processing

# %%
import os
import requests
import shapely
import json

import matplotlib.pyplot as plt #plotting
import pandas as pd
import numpy as np
import scipy.stats as stat
#make sure plots are embedded into the notebook
# %matplotlib inline
#import statsmodels.formula.api as smf
import itertools
import geopandas as gpd
from shapely.geometry import Point, Polygon
from sklearn.metrics import silhouette_score
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import geopandas as gpd
import pylab as pl
import io
import pylab as pl

from geopandas import GeoDataFrame
from geopandas.tools import sjoin
try:
    import ipywidgets as widgets
    hasWidgets = True
except ImportError:
    hasWidgets = False
from sklearn.linear_model import LogisticRegression
from sklearn import svm
# from sklearn.metrics import confusion_matrix
# from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
# from sklearn.metrics import precision_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report
import matplotlib.pylab
import sklearn.preprocessing as preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['Polygon', 'linalg']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
weights_results = ['gent00_16.csv','Ongoing_adv_gent.csv',\
'pct_ch_hinc00_16.csv','pct_ch_medrent00_16.csv','pct_ch_medhval00_16.csv',\
'pct_ch_percol00_16.csv',
'Supergent16.csv']
weights_results
# Out:
# ['gent00_16.csv',
#  'Ongoing_adv_gent.csv',
#  'pct_ch_hinc00_16.csv',
#  'pct_ch_medrent00_16.csv',
#  'pct_ch_medhval00_16.csv',
#  'pct_ch_percol00_16.csv']

# %%
weights_df_list = []
for file in weights_results:
    print(file)
    print('./Results_NYC/4_CENSUS_FQ_PCA_TWITTER'+file[:-4]+'NYC.csv')
    temp = pd.read_csv('./Results_PCA_NYC/4_CENSUS_FQ_PCA_TWITTER'+file[:-4]+'NYC.csv')
    temp.rename(columns={'Unnamed: 0':'St_method'}, inplace=True)
    weights_df_list.append(temp)
# Out:
# gent00_16.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTERgent00_16NYC.csv
# Ongoing_adv_gent.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTEROngoing_adv_gentNYC.csv
# pct_ch_hinc00_16.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTERpct_ch_hinc00_16NYC.csv
# pct_ch_medrent00_16.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTERpct_ch_medrent00_16NYC.csv
# pct_ch_medhval00_16.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTERpct_ch_medhval00_16NYC.csv
# pct_ch_percol00_16.csv
# ./Results_NYC/4_CENSUS_FQ_PCA_TWITTERpct_ch_percol00_16NYC.csv

# %%
binary_typs = []
for w in weights_results:
    print(w)
    binary_typs.append(w[:-4])
binary_typs
# Out:
# gent00_16.csv
# Ongoing_adv_gent.csv
# pct_ch_hinc00_16.csv
# pct_ch_medrent00_16.csv
# pct_ch_medhval00_16.csv
# pct_ch_percol00_16.csv
# ['gent00_16',
#  'Ongoing_adv_gent',
#  'pct_ch_hinc00_16',
#  'pct_ch_medrent00_16',
#  'pct_ch_medhval00_16',
#  'pct_ch_percol00_16']

# %%
weights_df_list[0].loc[0][1:].abs().sort_values(ascending=False)[:10].index[::-1]
# Out:
# Index(['medhval00', 'pop00', 'neighbor_tweets', 'total_users', 'local_tweets',
#        'hinc00', 'medhval90', 'other_tweets', 'hinc90', 'total_tweets'],
#       dtype='object')

# %%
top10_pd = pd.DataFrame()
for i, binary_target in enumerate(binary_typs):
    print(i, binary_target)
    for st_method in list(weights_df_list[i].index):
        print('st_method',st_method)
        pd_series_by_st_method = weights_df_list[i].loc[st_method]
        for k, variable in enumerate(pd_series_by_st_method[1:].abs().sort_values(ascending=False)[:10].index[::-1]):
            print(k,variable)
            top10_pd.loc[st_method,variable] = k
top10_pd
# Out:
# 0 gent00_16
# st_method 0
# 0 medhval00
# 1 pop00
# 2 neighbor_tweets
# 3 total_users
# 4 local_tweets
# 5 hinc00
# 6 medhval90
# 7 other_tweets
# 8 hinc90
# 9 total_tweets
# st_method 1
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 2
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 3
# 0 155
# 1 53
# 2 343
# 3 206
# 4 238
# 5 281
# 6 vuln00
# 7 vulnrisk00
# 8 per_rent_00
# 9 distToHighVisitorTract
# st_method 4
# 0 130
# 1 medrent00
# 2 155
# 3 abm_dif_9000
# 4 hinc00
# 5 edudiff9000
# 6 distToHighVisitorTract
# 7 per_rent_00
# 8 vuln00
# 9 vulnrisk00
# st_method 5
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 6
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 7
# 0 155
# 1 53
# 2 343
# 3 206
# 4 238
# 5 281
# 6 vuln00
# 7 vulnrisk00
# 8 per_rent_00
# 9 distToHighVisitorTract
# st_method 8
# 0 155
# 1 53
# 2 343
# 3 206
# 4 238
# 5 281
# 6 vuln00
# 7 vulnrisk00
# 8 per_rent_00
# 9 distToHighVisitorTract
# st_method 9
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 10
# 0 261
# 1 138
# 2 265
# 3 217
# 4 84
# 5 hinc90
# 6 123
# 7 83
# 8 distToMHI
# 9 vuln00
# st_method 11
# 0 155
# 1 53
# 2 343
# 3 206
# 4 238
# 5 281
# 6 vuln00
# 7 vulnrisk00
# 8 per_rent_00
# 9 distToHighVisitorTract
# 1 Ongoing_adv_gent
# st_method 0
# 0 ch_all_li_count90_00
# 1 medrent00
# 2 Unnamed: 0.1
# 3 pop00
# 4 total_tweets
# 5 medhval90
# 6 other_tweets
# 7 local_tweets
# 8 hinc00
# 9 hinc90
# st_method 1
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_y
# st_method 2
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_x
# st_method 3
# 0 155
# 1 82
# 2 Thursday_oddratio
# 3 320
# 4 180
# 5 31
# 6 distToHighVisitorTract
# 7 per_rent_00
# 8 gent90_00_x
# 9 gent90_00_y
# st_method 4
# 0 abm_dif_9000
# 1 distToHighVisitorTract
# 2 medrent00
# 3 per_rent_90
# 4 31
# 5 per_rent_00
# 6 vulnrisk00
# 7 vuln00
# 8 gent90_00_x
# 9 gent90_00_y
# st_method 5
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_x
# st_method 6
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_x
# st_method 7
# 0 155
# 1 82
# 2 Thursday_oddratio
# 3 320
# 4 180
# 5 31
# 6 distToHighVisitorTract
# 7 per_rent_00
# 8 gent90_00_x
# 9 gent90_00_y
# st_method 8
# 0 155
# 1 82
# 2 Thursday_oddratio
# 3 320
# 4 180
# 5 31
# 6 distToHighVisitorTract
# 7 per_rent_00
# 8 gent90_00_x
# 9 gent90_00_y
# st_method 9
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_x
# st_method 10
# 0 hinc00
# 1 248
# 2 118
# 3 125
# 4 260
# 5 220
# 6 192
# 7 distToMHI
# 8 vuln00
# 9 gent90_00_x
# st_method 11
# 0 155
# 1 82
# 2 Thursday_oddratio
# 3 320
# 4 180
# 5 31
# 6 distToHighVisitorTract
# 7 per_rent_00
# 8 gent90_00_x
# 9 gent90_00_y
# 2 pct_ch_hinc00_16
# st_method 0
# 0 userwith5_count
# 1 Unnamed: 0.1
# 2 medhval00
# 3 total_tweets
# 4 hinc90
# 5 total_users
# 6 pop00
# 7 local_tweets
# 8 hinc00
# 9 other_tweets
# st_method 1
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 2
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 3
# 0 11
# 1 5
# 2 14
# 3 75
# 4 43
# 5 pop00
# 6 1
# 7 ch_all_li_count90_00
# 8 2
# 9 hinc00
# st_method 4
# 0 75
# 1 11
# 2 18
# 3 pop00
# 4 0
# 5 14
# 6 Unnamed: 0.1
# 7 1
# 8 2
# 9 hinc00
# st_method 5
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 6
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 7
# 0 11
# 1 5
# 2 14
# 3 75
# 4 43
# 5 pop00
# 6 1
# 7 ch_all_li_count90_00
# 8 2
# 9 hinc00
# st_method 8
# 0 11
# 1 5
# 2 14
# 3 75
# 4 43
# 5 pop00
# 6 1
# 7 ch_all_li_count90_00
# 8 2
# 9 hinc00
# st_method 9
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 10
# 0 111
# 1 121
# 2 medrent90
# 3 22
# 4 total_users
# 5 hinc00
# 6 pop00
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 2
# st_method 11
# 0 11
# 1 5
# 2 14
# 3 75
# 4 43
# 5 pop00
# 6 1
# 7 ch_all_li_count90_00
# 8 2
# 9 hinc00
# 3 pct_ch_medrent00_16
# st_method 0
# 0 userwith5_count
# 1 pop00
# 2 medhval00
# 3 neighbor_tweets
# 4 local_tweets
# 5 total_users
# 6 hinc00
# 7 total_tweets
# 8 other_tweets
# 9 hinc90
# st_method 1
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 2
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 3
# 0 216
# 1 321
# 2 139
# 3 108
# 4 233
# 5 74
# 6 8
# 7 12
# 8 3
# 9 medrent00
# st_method 4
# 0 popden00
# 1 108
# 2 74
# 3 percol00
# 4 TOD
# 5 8
# 6 afford90
# 7 12
# 8 3
# 9 medrent00
# st_method 5
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 6
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 7
# 0 216
# 1 321
# 2 139
# 3 108
# 4 233
# 5 74
# 6 8
# 7 12
# 8 3
# 9 medrent00
# st_method 8
# 0 216
# 1 321
# 2 139
# 3 108
# 4 233
# 5 74
# 6 8
# 7 12
# 8 3
# 9 medrent00
# st_method 9
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 10
# 0 84
# 1 183
# 2 Friday_oddratio
# 3 edudiff9000
# 4 pnhblk00
# 5 202
# 6 2
# 7 distToMHI
# 8 Unnamed: 0.1
# 9 medrent90
# st_method 11
# 0 216
# 1 321
# 2 139
# 3 108
# 4 233
# 5 74
# 6 8
# 7 12
# 8 3
# 9 medrent00
# 4 pct_ch_medhval00_16
# st_method 0
# 0 userwith5_count
# 1 neighbor_tweets
# 2 medhval00
# 3 pop00
# 4 total_tweets
# 5 total_users
# 6 hinc00
# 7 local_tweets
# 8 hinc90
# 9 other_tweets
# st_method 1
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 2
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 3
# 0 293
# 1 131
# 2 106
# 3 59
# 4 1
# 5 3
# 6 ch_all_li_count90_00
# 7 278
# 8 16
# 9 medhval00
# st_method 4
# 0 293
# 1 hinc00
# 2 new_medhval90
# 3 2
# 4 17
# 5 ch_all_li_count90_00
# 6 278
# 7 0
# 8 16
# 9 medhval00
# st_method 5
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 6
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 7
# 0 293
# 1 131
# 2 106
# 3 59
# 4 1
# 5 3
# 6 ch_all_li_count90_00
# 7 278
# 8 16
# 9 medhval00
# st_method 8
# 0 293
# 1 131
# 2 106
# 3 59
# 4 1
# 5 3
# 6 ch_all_li_count90_00
# 7 278
# 8 16
# 9 medhval00
# st_method 9
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 10
# 0 357
# 1 34
# 2 340
# 3 290
# 4 268
# 5 hinc90
# 6 2
# 7 Unnamed: 0.1
# 8 medhval00
# 9 1
# st_method 11
# 0 293
# 1 131
# 2 106
# 3 59
# 4 1
# 5 3
# 6 ch_all_li_count90_00
# 7 278
# 8 16
# 9 medhval00
# 5 pct_ch_percol00_16
# st_method 0
# 0 medrent00
# 1 neighbor_tweets
# 2 pop00
# 3 total_users
# 4 other_tweets
# 5 total_tweets
# 6 medhval00
# 7 medhval90
# 8 hinc00
# 9 hinc90
# st_method 1
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 2
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 3
# 0 carcommuters_00
# 1 84
# 2 297
# 3 122
# 4 15
# 5 170
# 6 149
# 7 339
# 8 edudiff9000
# 9 percol00
# st_method 4
# 0 0
# 1 15
# 2 325
# 3 medrent90
# 4 34
# 5 distToMHI
# 6 carcommuters_00
# 7 percol90
# 8 edudiff9000
# 9 percol00
# st_method 5
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 6
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 7
# 0 carcommuters_00
# 1 84
# 2 297
# 3 122
# 4 15
# 5 170
# 6 149
# 7 339
# 8 edudiff9000
# 9 percol00
# st_method 8
# 0 carcommuters_00
# 1 84
# 2 297
# 3 122
# 4 15
# 5 170
# 6 149
# 7 339
# 8 edudiff9000
# 9 percol00
# st_method 9
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 10
# 0 41
# 1 78
# 2 238
# 3 medhval00
# 4 60
# 5 Unnamed: 0.1
# 6 55
# 7 15
# 8 2
# 9 percol00
# st_method 11
# 0 carcommuters_00
# 1 84
# 2 297
# 3 122
# 4 15
# 5 170
# 6 149
# 7 339
# 8 edudiff9000
# 9 percol00
#     medhval00  pop00  neighbor_tweets  total_users  local_tweets  hinc00  \
# 0         6.0    2.0              1.0          3.0           7.0     8.0
# 1         3.0    6.0              NaN          4.0           NaN     5.0
# 2         3.0    6.0              NaN          4.0           NaN     5.0
# 3         9.0    5.0              NaN          NaN           NaN     9.0
# 4         9.0    3.0              NaN          NaN           NaN     1.0
# 5         3.0    6.0              NaN          4.0           NaN     5.0
# 6         3.0    6.0              NaN          4.0           NaN     5.0
# 7         9.0    5.0              NaN          NaN           NaN     9.0
# 8         9.0    5.0              NaN          NaN           NaN     9.0
# 9         3.0    6.0              NaN          4.0           NaN     5.0
# 10        3.0    6.0              NaN          4.0           NaN     5.0
# 11        9.0    5.0              NaN          NaN           NaN     9.0
#
#     medhval90  other_tweets  hinc90  total_tweets    ...      55   15  \
# 0         7.0           4.0     9.0           5.0    ...     NaN  NaN
# 1         NaN           NaN     5.0           NaN    ...     6.0  7.0
# 2         NaN           NaN     5.0           NaN    ...     6.0  7.0
# 3         NaN           NaN     NaN           NaN    ...     NaN  4.0
# 4         NaN           NaN     NaN           NaN    ...     NaN  1.0
# 5         NaN           NaN     5.0           NaN    ...     6.0  7.0
# 6         NaN           NaN     5.0           NaN    ...     6.0  7.0
# 7         NaN           NaN     NaN           NaN    ...     NaN  4.0
# 8         NaN           NaN     NaN           NaN    ...     NaN  4.0
# 9         NaN           NaN     5.0           NaN    ...     6.0  7.0
# 10        NaN           NaN     5.0           NaN    ...     6.0  7.0
# 11        NaN           NaN     NaN           NaN    ...     NaN  4.0
#
#     carcommuters_00  297  122  170  149  339  325  percol90
# 0               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 1               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 2               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 3               0.0  2.0  3.0  5.0  6.0  7.0  NaN       NaN
# 4               6.0  NaN  NaN  NaN  NaN  NaN  2.0       7.0
# 5               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 6               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 7               0.0  2.0  3.0  5.0  6.0  7.0  NaN       NaN
# 8               0.0  2.0  3.0  5.0  6.0  7.0  NaN       NaN
# 9               NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 10              NaN  NaN  NaN  NaN  NaN  NaN  NaN       NaN
# 11              0.0  2.0  3.0  5.0  6.0  7.0  NaN       NaN
#
# [12 rows x 105 columns]

# %%
print(weights_results[3])
st_method = 8
print(st_method, (weights_df_list[3].loc[st_method][0]))
weights_df_list[3].loc[st_method][1:].abs().sort_values(ascending=False)[:10].index[::-1]
# Out:
# pct_ch_medrent00_16.csv
# 8 Logit_Minmaxed
# Index(['216', '321', '139', '108', '233', '74', '8', '12', '3', 'medrent00'], dtype='object')

# %%
print(top10_pd.sum(axis=0).sort_values(ascending=False)[:10])
top10_pd.sum(axis=0).sort_values(ascending=False)[:10].plot(kind='bar', title = 'Top 10 Most Important Weights for All 84 Models of Foursquare PCA, Twitter, and Census Only in NYC')
plt.show()
top10_pd.sum(axis=0).sort_values(ascending=False)[:50].plot(kind='bar', figsize = (15,15), title = 'Top 10 Most Important Weights for All 84 Models of Foursquare and Census')
# Out:
# percol00       99.0
# gent90_00_x    85.0
# 2              83.0
# vuln00         79.0
# 1              77.0
# hinc00         75.0
# medhval00      69.0
# pop00          61.0
# 15             59.0
# edudiff9000    58.0
# dtype: float64

# %%
# top10_pd = pd.DataFrame():
# for binary_variable in binary_variables:
#     top10_pd[binary_variable] = weights_df[0].loc[0][1:].abs().sort_values(ascending=False)[:10].index
