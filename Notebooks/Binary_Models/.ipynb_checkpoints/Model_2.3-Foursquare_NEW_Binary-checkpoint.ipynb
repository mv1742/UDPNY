# %% [markdown]
# # Analysis of Foursquare Data
# # NYU - CUSP UDP Capstone
# # Foursquare + NYC Merge by CT
# ## Brief
# This notebook
# 1. Part I. Data Processing
#
#     - import Foursquare data
#     - imports the Census Tract shapefile
#     - import Typologies
#     - merges topologies
#     - Spatail join by Census Tract
#     - merges topologies
#     - map topologies
#     - map Businesses
# 1. Part II. Data Processing
#     - Performs a classifcation task on Typologies
# ###  You can refer to https://github.com/mv1742/updny_2

# %% [markdown]
# # Part I. Data Processing

# %%
import os
import requests
import shapely
import json

import matplotlib.pyplot as plt #plotting
import pandas as pd
import numpy as np
import scipy.stats as stat
#make sure plots are embedded into the notebook
# %matplotlib inline
#import statsmodels.formula.api as smf
import itertools
import geopandas as gpd
from shapely.geometry import Point, Polygon
from sklearn.metrics import silhouette_score
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
# from sklearn.mixture import GaussianMixture
from scipy import linalg
import matplotlib as mpl
import pandas as pd
from sklearn import preprocessing
from scipy.cluster.hierarchy import dendrogram, linkage  # for hierarchical clustering
from scipy.cluster.hierarchy import fcluster
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
import geopandas as gpd
import pylab as pl
import io
import pylab as pl

from geopandas import GeoDataFrame
from geopandas.tools import sjoin
try:
    import ipywidgets as widgets
    hasWidgets = True
except ImportError:
    hasWidgets = False
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['Polygon', 'linalg']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # NYU - CUSP UDP Capstone
# # Foursquare + NYC Merge by CT
# ## Brief
# This notebook
# - import Foursquare data
# - imports the Census Tract shapefile
# - import Typologies
# - merges topologies
# - Spatail join by Census Tract
# - merges topologies
# - map topologies
# - map Businesses
# - outputs a .csv of the results
# - You can refer to https://github.com/mv1742/updny_2

# %% [markdown]
# # Foursquare Data
# - import Foursquare data

# %%
data = gpd.read_file('NYU_March2018_subset30.geojson')

# %%
(list(data.columns)), data.shape
# Out:
# (['id',
#   'Place Name',
#   'Rating',
#   'Checkins',
#   'Users',
#   'Visits',
#   'Pricing',
#   'Type',
#   'Category',
#   'Class',
#   'geometry'],
#  (106287, 11))

# %%
data.head(1)
# Out:
#                          id         Place Name  Rating  Checkins  Users  \
# 0  50ad0afce4b0b4a7430e2268  Terry's Wine Shop     8.8       294    217
#
#    Visits Pricing       Type     Category     Class  \
# 0     337    None  Wine Shop  Consumption  Optional
#
#                                        geometry
# 0  POINT (-74.00034036700906 40.73518392010902)

# %%
list(data.columns)[-4:-1]
# Out:
# ['Type', 'Category', 'Class']

# %%
X_dummies = data[list(data.columns)[-4:-1]]
print(X_dummies.shape)
X_dummies = pd.get_dummies(X_dummies)
Fq_dummies = pd.concat([data, X_dummies], axis=1, join='inner')  
Fq_dummies.shape
# Out:
# (106287, 3)
# (106287, 716)

# %% [markdown]
# # Census Tract shapefile
# - imports the Census Tract shapefile

# %%
# create the directory for shapefiles and set the environmental variable to it

#masterdata = os.getenv("Master")
#if masterdata is None:
#    os.environ["Master"] = "{}/Capstone/udpny_2".format(os.getenv("HOME"))
#    masterdata = os.getenv("Master")
#    print("Warning: Master environmental variable not found and set by code, please review!")
#print("Master: {}".format(masterdata))

# %%
# create the directory for shapefiles and set the environmental variable to it

# masterdata = os.getenv("Master")
# if masterdata is None:
#     os.environ["Master"] = "{}/Capstone/udpny_2".format(os.getenv("HOME"))
#     masterdata = os.getenv("Master")
#     print("Warning: Master environmental variable not found and set by code, please review!")
# print("Master: {}".format(masterdata))
# def getGeoDataFrameFromShpFileZipUrl(url):
#     '''
#     This function downloads the zip file, unzips it into the dorectory 
#     pointed to by PUIdata environment variable. Then it 
#     reads it into a gepandas dataframe
#     '''
    
#     folderName = 'shape'+ \
#         str(len(os.listdir(os.getenv('TaxiData')))+1)
#     os.makedirs(os.getenv('Master') + '/' + folderName)
#     urlretrieve(url, "region.zip")
#     os.system('unzip -d $Master'+'/'+folderName+' region.zip')
#     filenames = [f for f in os.listdir(os.getenv('Master') + '/' + folderName) if f.endswith('.shp') ]
#     shapeFile = filenames[0]
#     shapeFilePath = os.getenv('Master') + '/' + folderName + '/' + shapeFile
#     return gpd.GeoDataFrame.from_file(shapeFilePath)

# %%
# url = 'https://planninglabs.carto.com/api/v2/sql?filename=region&q=SELECT%20%2A%20FROM%20region_censustract_v0&format=SHP'
# NYCzip = getGeoDataFrameFromShpFileZipUrl(url)
NYCzip=gpd.read_file('Censustracts/region.shp')
NYCzip.plot()

# %%
NYCzip.columns
# Out:
# Index(['aland_mi', 'objectid', 'statefp', 'countyfp', 'tractce', 'geoid',
#        'name', 'namelsad', 'mtfcc', 'funcstat', 'aland', 'awater', 'intptlat',
#        'intptlon', 'shape_leng', 'shape_area', 'atotal', 'atotal_mi',
#        'cartodb_id', 'geoid_1', 'hou16', 'hou16moe', 'hou16cv', 'houv16',
#        'houv16moe', 'houv16cv', 'houo16', 'houo16moe', 'houo16cv', 'hour16',
#        'hour16moe', 'hour16cv', 'emtot15', 'empr15', 'emoff15', 'emins15',
#        'emind15', 'emser15', 'emoth15', 'geometry'],
#       dtype='object')

# %%
NYCzip.rename(columns={"geoid": "GEOID"},inplace=True)
NYCzip.GEOID = NYCzip.GEOID.astype(int)
cols = ['GEOID','geometry']
NYCzip = NYCzip.loc[:,cols]
#NYCzipgdp.plot(column='GEOID',legend = True)
NYCzip.shape
NYCzip.isnull().sum()
# Out:
# GEOID       0
# geometry    0
# dtype: int64

# %%
figure, ax = plt.subplots(figsize=(15, 15))
NYCzip.plot(column='GEOID',legend = True, ax=ax)

# %% [markdown]
# # Typologies
# - import Typologies
# - merges topologies
# - map topologies

# %%
Typologiespd=pd.read_csv('NY_final_data_for_typologies_1.19.19.csv')
Typologiesgdp = gpd.GeoDataFrame(Typologiespd)
len(Typologiesgdp.columns)
# Out:
# 82

# %%
Typologiesgdp['Type_1.19'].unique()
# Out:
# array(['VHI - Super Gentrification or Exclusion',
#        'MHI - Ongoing Exclusion',
#        'MHI - Stable or Early Stage of Exclusion',
#        'MHI - Advanced Exclusion', 'LI - At Risk of Gentrification',
#        'MHI - Advanced Gentrification',
#        'LI - Not Losing Low-Income Households',
#        'LI - Ongoing Displacement of Low-Income Households',
#        'Missing Data', 'LI - Ongoing Gentrification', nan], dtype=object)

# %%
Typologiesgdp['Type_binary'] = Typologiesgdp['Type_1.19'].copy()
Typologiesgdp['Type_binary'].replace('VHI - Super Gentrification or Exclusion',1,inplace=True)
Typologiesgdp['Type_binary'].replace('MHI - Ongoing Exclusion',0,inplace=True)
Typologiesgdp['Type_binary'].replace('MHI - Stable or Early Stage of Exclusion',0,inplace=True)
Typologiesgdp['Type_binary'].replace('MHI - Advanced Exclusion', 0,inplace=True)
Typologiesgdp['Type_binary'].replace('MHI - Advanced Gentrification',1,inplace=True)
Typologiesgdp['Type_binary'].replace('LI - At Risk of Gentrification',0,inplace=True)
Typologiesgdp['Type_binary'].replace('LI - Ongoing Gentrification',1,inplace=True)
Typologiesgdp['Type_binary'].replace('LI - Not Losing Low-Income Households',0,inplace=True)
Typologiesgdp['Type_binary'].replace('LI - Ongoing Displacement of Low-Income Households',0,inplace=True)
Typologiesgdp['Type_binary'].replace('Missing Data',0,inplace=True)
Typologiesgdp['Type_binary'].replace(nan,0,inplace=True)

# %%
Typologiesgdp['Type_binary'].unique()
Typologiesgdp['Type_binary'].value_counts().plot(kind='bar')
Typologiesgdp['Type_binary'].value_counts()/Typologiesgdp['Type_binary'].value_counts().sum()
# Out:
# 0.0    0.818988
# 1.0    0.181012
# Name: Type_binary, dtype: float64

# %%
Typologiesgdp['Type_binary'].value_counts().sum()
# Out:
# 5298

# %%
Typologiesgdp['Type_1.19'] = Typologiesgdp['Type_binary'].copy()

# %%
# Typologiesgdp.to_csv('typologies_binary.csv')
Typologiesgdp.drop(columns='Type_binary', inplace=True)

# %%
Typologiesgdp.rename(columns={'geoid': "GEOID"},inplace=True)
Typologiesgdp.tail()
# cols_typ = ['GEOID','Type_1.19']
print(type(Typologiesgdp.iloc[:,0][0]))
#Typologies.rename(columns={'\ufeffgeoid': "GEOID"},inplace=True)
#Typologiesgdp.geoid = Typologies.iloc[:,0]
# Typologiesgdp = Typologiesgdp.loc[:,cols_typ]
Typologiesgdp.head()
# Out:
# <class 'numpy.float64'>
#           GEOID                                     typology_old    medrent90  \
# 0  9.001010e+09                       MHI - At Risk of Exclusion  1001.000000
# 1  9.001010e+09                         MHI - Advanced Exclusion  1000.999968
# 2  9.001010e+09                         MHI - Advanced Exclusion  1000.999996
# 3  9.001010e+09  MHI - Displacement of LI hh - Ongoing Exclusion  1001.000000
# 4  9.001010e+09                       MHI - At Risk of Exclusion  1001.000000
#
#    medrent00  medrent16    medhval90  medhval00  medhval16  percol90  \
# 0     1601.0     1510.0  500001.0000  1000001.0  1494000.0  0.516292
# 1     1244.0     1628.0  500001.0059  1000000.0  2000000.0  0.619490
# 2      833.0     2113.0  499472.1825  1000000.0  2000000.0  0.602177
# 3     1791.0     2250.0  500001.0000   769300.0  1459900.0  0.552381
# 4     1967.0     1900.0  500001.0000  1000001.0  2000001.0  0.647751
#
#    percol00               ...                ch_all_li_count90_00  \
# 0  0.354071               ...                        -19.55026245
# 1  0.748477               ...                         48.47680664
# 2  0.704225               ...                        -13.43575287
# 3  0.342164               ...                         38.88369751
# 4  0.357744               ...                        -19.13200378
#
#    ch_all_li_count00_16  liloss9016  per_limove16  per_limove09  exclusion  \
# 0           136.0813599           0  0.6400990486  0.3994323015          0
# 1          -7.125137329           0  0.4056389332  0.5011153221          1
# 2           85.95057678           0  0.4642397463  0.3962181509          0
# 3          -84.88815308           0  0.3480436504  0.4504249096          1
# 4           58.64305115           0  0.3950261176  0.4935227931          1
#
#    popgrowth0016     Incch0016   li_hh_16          Typology_final_1.19.19
# 0            0.0  0.5498838311  401.65921  LI - At Risk of Gentrification
# 1            0.0  0.8620689655  213.51843  LI - At Risk of Gentrification
# 2            0.0  0.7325793103  180.98723  LI - At Risk of Gentrification
# 3            1.0   1.192524372  363.08643  LI - At Risk of Gentrification
# 4            0.0  0.8974181129  310.05765  LI - At Risk of Gentrification
#
# [5 rows x 82 columns]

# %%
merged = NYCzip.merge(Typologiesgdp,on='GEOID')
merged.tail()
# Out:
#             GEOID                                           geometry  \
# 5285  36061021703  POLYGON ((-73.94607800039937 40.82126399983373...
# 5286  36061021800  POLYGON ((-73.94872800029694 40.80333100022552...
# 5287  36061021900  POLYGON ((-73.9554510000636 40.81937700004859,...
# 5288  36061022102  POLYGON ((-73.94515500010318 40.82087599992749...
# 5289  36047152200  POLYGON ((-73.96408699991511 40.6444069999831,...
#
#                                            typology_old   medrent90  \
# 5285                                       Missing Data  324.000003
# 5286                        LI - Ongoing Gentrification  283.000000
# 5287              LI - Not Losing Low-Income Households  310.999994
# 5288  LI - Ongoing Displacement of Low- Income House...  329.000000
# 5289                         MHI - At Risk of Exclusion  554.271997
#
#        medrent00  medrent16    medhval90    medhval00  medhval16  percol90  \
# 5285  533.000005        0.0       0.0000       0.0000        0.0  0.000095
# 5286  461.000000     1184.0          NaN  392300.0000        NaN  0.075093
# 5287  427.000000      528.0       0.0000  625000.0000        0.0  0.055690
# 5288  582.000000     1196.0  187500.0000  175000.0000   537900.0  0.161512
# 5289  774.956522     1532.0  300142.2554  361840.6072  1146400.0  1.036555
#
#                ...            ch_all_li_count90_00  ch_all_li_count00_16  \
# 5285           ...                    0.2853928208         -0.2856110036
# 5286           ...                     60.11474609           268.1595459
# 5287           ...                     514.1179199          -57.55786133
# 5288           ...                     194.1737671           22.30535889
# 5289           ...                    -76.31544495           30.12321472
#
#       liloss9016  per_limove16     per_limove09  exclusion  popgrowth0016  \
# 5285           0  0.6940270066  0.0005622510216          0            1.0
# 5286           0   0.496555984       0.65008986          1            1.0
# 5287           0   0.719860971     0.5384375453          0            0.0
# 5288           0  0.7885694504     0.5269782543          0            1.0
# 5289           0  0.6077033281     0.7516720891          1            1.0
#
#          Incch0016    li_hh_16  Typology_final_1.19.19
# 5285           NaN     0.00000  MHI - Stable Exclusion
# 5286   1.501362508  1671.15310  MHI - Stable Exclusion
# 5287  0.8618693201  1742.72380  MHI - Stable Exclusion
# 5288  0.9512603314   662.92755  MHI - Stable Exclusion
# 5289   1.007667239   284.00000  MHI - Stable Exclusion
#
# [5 rows x 83 columns]

# %%
print(type(merged),merged.shape)
mergedgpd = gpd.GeoDataFrame(merged)
mergedgpd.shape
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'> (5290, 83)
# (5290, 83)

# %%
figure, ax = plt.subplots(figsize=(15, 15))
mergedgpd.plot(column='Type_1.19',legend = True, ax=ax)

# %%
Typologiesgdp.rename(columns={'geoid': "GEOID"},inplace=True)
Typologiesgdp.tail()
cols_typ = ['GEOID','hinc00','hinc16','pct_ch_hinc00_16']
print(type(Typologiesgdp.iloc[:,0][0]))
#Typologies.rename(columns={'\ufeffgeoid': "GEOID"},inplace=True)
#Typologiesgdp.geoid = Typologies.iloc[:,0]
Typologiesgdp = Typologiesgdp.loc[:,cols_typ]
Typologiesgdp.head()
# Out:
# <class 'numpy.float64'>
#           GEOID     hinc00    hinc16  pct_ch_hinc00_16
# 0  9.001010e+09  273976.05  150655.0         -0.450116
# 1  9.001010e+09  290000.00  250000.0         -0.137931
# 2  9.001010e+09  290000.00  212448.0         -0.267421
# 3  9.001010e+09  157543.95  187875.0          0.192524
# 4  9.001010e+09  246540.60  221250.0         -0.102582

# %%
merged = NYCzip.merge(Typologiesgdp,on='GEOID')
list(merged.columns)
print(type(merged),merged.shape)
mergedgpd = gpd.GeoDataFrame(merged)
mergedgpd.shape
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'> (5290, 5)
# (5290, 5)

# %%
mergedgpd
# Out:
#             GEOID                                           geometry  \
# 0     34013021601  POLYGON ((-74.3228040001045 40.90883400018899,...
# 1     34003031100  POLYGON ((-74.08304199968846 40.78623200040653...
# 2     34003036200  POLYGON ((-74.03536299980257 40.82861799992076...
# 3     34017003500  POLYGON ((-74.04668899959766 40.72066899957468...
# 4     34017015500  POLYGON ((-74.01458600034361 40.79119299985706...
# 5     34013013200  POLYGON ((-74.21338700040968 40.73388700028482...
# 6     34027044501  (POLYGON ((-74.56219999983014 40.9012120003335...
# 7     34023004500  (POLYGON ((-74.25451090392684 40.5403372012258...
# 8     34003007001  POLYGON ((-73.96304000019583 40.98273799985878...
# 9     34003019102  POLYGON ((-73.95468099962847 40.8616329998631,...
# 10    34025812502  POLYGON ((-74.41671499969745 40.16536199965662...
# 11    34035053604  POLYGON ((-74.66720900039509 40.61590999974675...
# 12    34003006202  POLYGON ((-73.97682500007369 40.82783299969318...
# 13    34023006203  POLYGON ((-74.47185199996979 40.44337200031759...
# 14    34027041706  POLYGON ((-74.37497500029599 40.89193299960826...
# 15    34031175801  POLYGON ((-74.12043500007513 40.85413000009949...
# 16    34023001300  POLYGON ((-74.41806599994592 40.49137799999475...
# 17    34003042400  POLYGON ((-74.07207000003049 40.94865900031262...
# 18    34035052201  POLYGON ((-74.44869000024333 40.65523100001066...
# 19    34029722600  (POLYGON ((-74.15031499694514 39.9957130046421...
# 20    34013012400  POLYGON ((-74.22998499960802 40.72519899983403...
# 21    34017005802  POLYGON ((-74.06878399958187 40.70096099995016...
# 22    34029738100  POLYGON ((-74.15706565722054 39.66940797912223...
# 23    34021004304  POLYGON ((-74.57339699997154 40.30089999973519...
# 24    34021003202  POLYGON ((-74.69171700013946 40.26829499981442...
# 25    34021003302  POLYGON ((-74.70642000008297 40.34599900025372...
# 26    34035052400  POLYGON ((-74.54900500018061 40.74093499975048...
# 27    34025801700  (POLYGON ((-74.19838800030597 40.4395070001479...
# 28    34025803900  (POLYGON ((-73.99465699289391 40.3776559991386...
# 29    34025804200  POLYGON ((-74.02655791928737 40.33947506740999...
# ...           ...                                                ...
# 5260  36119014400  POLYGON ((-73.89574300033918 41.29385300011587...
# 5261  36059981100  POLYGON ((-73.60149399994815 40.81937600000241...
# 5262  36059416401  POLYGON ((-73.69029500041397 40.58880603213396...
# 5263  36059416402  POLYGON ((-73.68128600044855 40.58838800040589...
# 5264  36059416801  POLYGON ((-73.63746478294019 40.59511384926169...
# 5265  36061016200  (POLYGON ((-73.93275567343714 40.7779632059886...
# 5266  36061016600  POLYGON ((-73.94516799980335 40.7908939995585,...
# 5267  36061016700  POLYGON ((-73.97690200002721 40.78509800027255...
# 5268  36061016800  POLYGON ((-73.94789599970061 40.79292799982733...
# 5269  36061017000  POLYGON ((-73.93864899955173 40.79155799960207...
# 5270  36061017100  POLYGON ((-73.97501600028815 40.78768700005503...
# 5271  36061019200  (POLYGON ((-73.92696300024225 40.7952420004180...
# 5272  36061017800  (POLYGON ((-73.93171837313743 40.7902700022167...
# 5273  36061018100  POLYGON ((-73.96417600042207 40.79236199980644...
# 5274  36061018200  POLYGON ((-73.93860300012834 40.79988300040021...
# 5275  36061018300  POLYGON ((-73.9694150001021 40.79536099961048,...
# 5276  36061018400  POLYGON ((-73.94182500032352 40.80124000002603...
# 5277  36061018500  POLYGON ((-73.96283399968931 40.79420300016837...
# 5278  36061018600  POLYGON ((-73.94697400034978 40.79996100039983...
# 5279  36061018800  POLYGON ((-73.93399099968484 40.79793200036153...
# 5280  36061020300  POLYGON ((-73.95827199975292 40.81062900042808...
# 5281  36061021000  (POLYGON ((-73.93260499962105 40.8115170000095...
# 5282  36061021100  POLYGON ((-73.95626900001432 40.81337500025604...
# 5283  36061021200  POLYGON ((-73.93575600013925 40.81532600029464...
# 5284  36061021400  POLYGON ((-73.93447500042095 40.81969700041622...
# 5285  36061021703  POLYGON ((-73.94607800039937 40.82126399983373...
# 5286  36061021800  POLYGON ((-73.94872800029694 40.80333100022552...
# 5287  36061021900  POLYGON ((-73.9554510000636 40.81937700004859,...
# 5288  36061022102  POLYGON ((-73.94515500010318 40.82087599992749...
# 5289  36047152200  POLYGON ((-73.96408699991511 40.6444069999831,...
#
#             hinc00    hinc16  pct_ch_hinc00_16
# 0     120523.99890  100977.0         -0.162183
# 1      72720.40000   69669.0         -0.041961
# 2      73386.24810   53462.0         -0.271498
# 3      84320.40000   81705.0         -0.031017
# 4      42744.55000   46161.0          0.079927
# 5      38177.52818   26684.0         -0.301055
# 6     114980.29360   81275.0         -0.293140
# 7      46405.38164   48641.0          0.048176
# 8     116736.60000  100250.0         -0.141229
# 9      76125.00000   85699.0          0.125767
# 10    126069.20140  128611.0          0.020162
# 11    135547.61070  118750.0         -0.123924
# 12     72961.09963   81273.0          0.113922
# 13    106195.10000   93958.0         -0.115232
# 14     81775.64929   64384.0         -0.212675
# 15     45032.50206   31567.0         -0.299017
# 16     79841.35000   73875.0         -0.074728
# 17    124476.70000  117381.0         -0.057004
# 18    131231.85720   99808.0         -0.239453
# 19     87000.00000   78966.0         -0.092345
# 20     39245.70000   28603.0         -0.271181
# 21    116427.75090  139500.0          0.198168
# 22     85187.50000   81188.0         -0.046949
# 23    218870.25000  203510.0         -0.070180
# 24    103153.00000   94375.0         -0.085097
# 25    111023.59670  112031.0          0.009074
# 26    141187.15620  128875.0         -0.087205
# 27     48749.00000   34669.0         -0.288826
# 28    143041.05000  106250.0         -0.257206
# 29    136076.71880  137652.0          0.011576
# ...            ...       ...               ...
# 5260   85435.22598   73354.0         -0.141408
# 5261       0.00000       NaN               NaN
# 5262   83322.79871   97368.0          0.168564
# 5263   83322.80157   93824.0          0.126030
# 5264   90587.30434  101442.0          0.119826
# 5265   33655.95000   27218.0         -0.191287
# 5266   38671.50000   37227.0         -0.037353
# 5267  135310.95360  131733.0         -0.026442
# 5268   31988.45000   31944.0         -0.001390
# 5269   39393.60000   30213.0         -0.233048
# 5270  104724.26950  112488.0          0.074135
# 5271   13514.00000   16278.0          0.204529
# 5272   33761.80000   42105.0          0.247120
# 5273   77171.90000   73194.0         -0.051546
# 5274   23284.10000   19333.0         -0.169691
# 5275   77182.05000  121344.0          0.572179
# 5276   20449.35000   25231.0          0.233829
# 5277   82374.50000  113018.0          0.372002
# 5278   20311.60000   30340.0          0.493728
# 5279   24238.20000   32690.0          0.348698
# 5280   50317.90000   37833.0         -0.248120
# 5281   37768.15000   29932.0         -0.207480
# 5282   50669.84374   47019.0         -0.072052
# 5283   42866.35000   54007.0          0.259893
# 5284   37392.60000   51538.0          0.378294
# 5285   34971.10032       NaN               NaN
# 5286   32256.70000   48429.0          0.501363
# 5287   25044.40000   21585.0         -0.138131
# 5288   43768.25000   41635.0         -0.048740
# 5289   84499.12500   85147.0          0.007667
#
# [5290 rows x 5 columns]

# %%
figure, ax = plt.subplots(figsize=(15, 15))
mergedgpd[mergedgpd.pct_ch_hinc00_16<1.5].plot(column='pct_ch_hinc00_16',legend = True, ax=ax)

# %%
# Explore pct_ch_hinc00_16
mergedgpd.pct_ch_hinc00_16.hist(bins = 10, figsize = (5,5))

# %%
# print(mergedgpd.hinc16.describe())
print(mergedgpd.pct_ch_hinc00_16.isnull().sum())
mergedgpd.pct_ch_hinc00_16.describe()
# Out:
# 80
# count    5210.000000
# mean       -0.012678
# std         0.248828
# min        -0.728638
# 25%        -0.152705
# 50%        -0.048447
# 75%         0.076208
# max         3.980326
# Name: pct_ch_hinc00_16, dtype: float64

# %%
# Check calculation
mergedgpd['check_00_16'] = (mergedgpd.hinc16-mergedgpd.hinc00)/mergedgpd.hinc00
cols_typ = ['GEOID','geometry','pct_ch_hinc00_16']
mergedgpd = mergedgpd.loc[:,cols_typ]
print(mergedgpd.shape)
# Out:
# (5290, 3)

# %%
mergedgpd.pct_ch_hinc00_16= mergedgpd.pct_ch_hinc00_16.replace(nan,mergedgpd.pct_ch_hinc00_16.mean())

mergedgpd =mergedgpd.dropna(how='all',axis=0)
print(mergedgpd.shape)
mergedgpd = mergedgpd.dropna(axis=0)
print(mergedgpd.shape)
cols_X = [i for i in mergedgpd.columns] #if (i != 'pct_ch_hinc00_16')&(i != 'GEOID')]
print(cols_X)
# Out:
# (5290, 3)
# (5290, 3)
# ['GEOID', 'geometry', 'pct_ch_hinc00_16']

# %%
X = mergedgpd.pct_ch_hinc00_16
X = np.asarray(X)
X.shape
X = X.reshape((len(X), 1))

X.shape
for i in numpy.arange(-1, 3, 0.5):
    print(i)
    print(mergedgpd.pct_ch_hinc00_16[(mergedgpd.pct_ch_hinc00_16< (i+0.5)) & (mergedgpd.pct_ch_hinc00_16>i)].describe())
# Out:
# -1.0
# count    12.000000
# mean     -0.554369
# std       0.065920
# min      -0.728638
# 25%      -0.557292
# 50%      -0.533475
# 75%      -0.515329
# max      -0.501800
# Name: pct_ch_hinc00_16, dtype: float64
# -0.5
# count    3228.000000
# mean       -0.143261
# std         0.102581
# min        -0.499862
# 25%        -0.205241
# 50%        -0.124934
# 75%        -0.061918
# max        -0.000124
# Name: pct_ch_hinc00_16, dtype: float64
# 0.0
# count    1851.000000
# mean        0.140788
# std         0.117739
# min         0.000017
# 25%         0.047467
# 50%         0.109209
# 75%         0.206988
# max         0.499484
# Name: pct_ch_hinc00_16, dtype: float64
# 0.5
# count    137.000000
# mean       0.680709
# std        0.138746
# min        0.501363
# 25%        0.560729
# 50%        0.640935
# 75%        0.789456
# max        0.996167
# Name: pct_ch_hinc00_16, dtype: float64
# 1.0
# count    19.000000
# mean      1.247010
# std       0.168026
# min       1.021731
# 25%       1.096507
# 50%       1.250499
# 75%       1.389158
# max       1.496298
# Name: pct_ch_hinc00_16, dtype: float64
# 1.5
# count    5.000000
# mean     1.594875
# std      0.094243
# min      1.510398
# 25%      1.519035
# 50%      1.557737
# 75%      1.663889
# max      1.723314
# Name: pct_ch_hinc00_16, dtype: float64
# 2.0
# count    3.000000
# mean     2.170922
# std      0.133583
# min      2.026165
# 25%      2.111666
# 50%      2.197168
# 75%      2.243301
# max      2.289434
# Name: pct_ch_hinc00_16, dtype: float64
# 2.5
# count    1.000000
# mean     2.838292
# std           NaN
# min      2.838292
# 25%      2.838292
# 50%      2.838292
# 75%      2.838292
# max      2.838292
# Name: pct_ch_hinc00_16, dtype: float64

# %%
mergedgpd['pct_ch_hinc00_16_0_15'] = (mergedgpd.pct_ch_hinc00_16> (0.15))
(mergedgpd.pct_ch_hinc00_16> (0.15)).sum()
# Out:
# 862

# %%
(mergedgpd.pct_ch_hinc00_16> (0.15)).sum()/len(mergedgpd)
# Out:
# 0.16294896030245748

# %%
mergedgpd['pct_ch_hinc00_16_0_15'].value_counts().plot(kind='bar')

# %% [markdown]
# # Spatail Join
# - Spatail join by Census Tract
# - map Businesses

# %%
mergedgpd.crs, data.crs, mergedgpd.shape, data.shape
# Out:
# (None, {'init': 'epsg:4326'}, (5290, 4), (106287, 11))

# %%
mergedgpd.crs = {'init' :'epsg:4326'}

# %%
mergedgpd.crs
# Out:
# {'init': 'epsg:4326'}

# %%
data_sjoined = gpd.sjoin(mergedgpd.drop(columns='pct_ch_hinc00_16_0_15'),Fq_dummies, op="contains")

# %%
list(data_sjoined.columns)
# Out:
# ['GEOID',
#  'geometry',
#  'pct_ch_hinc00_16',
#  'index_right',
#  'id',
#  'Place Name',
#  'Rating',
#  'Checkins',
#  'Users',
#  'Visits',
#  'Pricing',
#  'Type',
#  'Category',
#  'Class',
#  'Type_ATM',
#  'Type_Accessories Store',
#  'Type_Acupuncturist',
#  'Type_Adult Boutique',
#  'Type_Adult Education Center',
#  'Type_Advertising Agency',
#  'Type_Afghan Restaurant',
#  'Type_African Restaurant',
#  'Type_Airport',
#  'Type_Airport Food Court',
#  'Type_Airport Gate',
#  'Type_Airport Lounge',
#  'Type_Airport Service',
#  'Type_Airport Terminal',
#  'Type_Airport Tram',
#  'Type_Alternative Healer',
#  'Type_American Restaurant',
#  'Type_Amphitheater',
#  'Type_Animal Shelter',
#  'Type_Antique Shop',
#  'Type_Apres Ski Bar',
#  'Type_Aquarium',
#  'Type_Arcade',
#  'Type_Arepa Restaurant',
#  'Type_Argentinian Restaurant',
#  'Type_Art Gallery',
#  'Type_Art Museum',
#  'Type_Art Studio',
#  'Type_Arts & Crafts Store',
#  'Type_Arts & Entertainment',
#  'Type_Asian Restaurant',
#  'Type_Assisted Living',
#  'Type_Astrologer',
#  'Type_Athletics & Sports',
#  'Type_Auditorium',
#  'Type_Australian Restaurant',
#  'Type_Austrian Restaurant',
#  'Type_Auto Dealership',
#  'Type_Auto Garage',
#  'Type_Auto Workshop',
#  'Type_Automotive Shop',
#  'Type_BBQ Joint',
#  'Type_Baby Store',
#  'Type_Badminton Court',
#  'Type_Bagel Shop',
#  'Type_Baggage Claim',
#  'Type_Bakery',
#  'Type_Ballroom',
#  'Type_Bank',
#  'Type_Bar',
#  'Type_Baseball Field',
#  'Type_Baseball Stadium',
#  'Type_Basketball Court',
#  'Type_Basketball Stadium',
#  'Type_Bath House',
#  'Type_Bathing Area',
#  'Type_Bavarian Restaurant',
#  'Type_Bay',
#  'Type_Beach',
#  'Type_Beach Bar',
#  'Type_Bed & Breakfast',
#  'Type_Beer Bar',
#  'Type_Beer Garden',
#  'Type_Beer Store',
#  'Type_Belgian Restaurant',
#  'Type_Betting Shop',
#  'Type_Big Box Store',
#  'Type_Bike Rental / Bike Share',
#  'Type_Bike Shop',
#  'Type_Bike Trail',
#  'Type_Bistro',
#  'Type_Board Shop',
#  'Type_Boarding House',
#  'Type_Boat Rental',
#  'Type_Boat or Ferry',
#  'Type_Bookstore',
#  'Type_Border Crossing',
#  'Type_Botanical Garden',
#  'Type_Boutique',
#  'Type_Bowling Alley',
#  'Type_Boxing Gym',
#  'Type_Brazilian Restaurant',
#  'Type_Breakfast Spot',
#  'Type_Brewery',
#  'Type_Bridal Shop',
#  'Type_Bridge',
#  'Type_Bubble Tea Shop',
#  'Type_Buddhist Temple',
#  'Type_Buffet',
#  'Type_Building',
#  'Type_Burger Joint',
#  'Type_Burmese Restaurant',
#  'Type_Burrito Place',
#  'Type_Bus Line',
#  'Type_Bus Station',
#  'Type_Bus Stop',
#  'Type_Business Center',
#  'Type_Business Service',
#  'Type_Butcher',
#  'Type_Cable Car',
#  'Type_Cafeteria',
#  'Type_Café',
#  'Type_Cajun / Creole Restaurant',
#  'Type_Cambodian Restaurant',
#  'Type_Camera Store',
#  'Type_Campaign Office',
#  'Type_Campground',
#  'Type_Candy Store',
#  'Type_Cantonese Restaurant',
#  'Type_Capitol Building',
#  'Type_Car Wash',
#  'Type_Caribbean Restaurant',
#  'Type_Carpet Store',
#  'Type_Casino',
#  'Type_Castle',
#  'Type_Caucasian Restaurant',
#  'Type_Cave',
#  'Type_Cemetery',
#  'Type_Cha Chaan Teng',
#  'Type_Chaat Place',
#  'Type_Check Cashing Service',
#  'Type_Cheese Shop',
#  'Type_Child Care Service',
#  'Type_Chinese Restaurant',
#  'Type_Chiropractor',
#  'Type_Chocolate Shop',
#  'Type_Christmas Market',
#  'Type_Church',
#  'Type_Churrascaria',
#  'Type_Circus',
#  'Type_Circus School',
#  'Type_City',
#  'Type_City Hall',
#  'Type_Climbing Gym',
#  'Type_Clothing Store',
#  'Type_Club House',
#  'Type_Cocktail Bar',
#  'Type_Coffee Shop',
#  'Type_College & University',
#  'Type_College Academic Building',
#  'Type_College Administrative Building',
#  'Type_College Arts Building',
#  'Type_College Auditorium',
#  'Type_College Baseball Diamond',
#  'Type_College Basketball Court',
#  'Type_College Bookstore',
#  'Type_College Cafeteria',
#  'Type_College Classroom',
#  'Type_College Communications Building',
#  'Type_College Cricket Pitch',
#  'Type_College Engineering Building',
#  'Type_College Football Field',
#  'Type_College Gym',
#  'Type_College History Building',
#  'Type_College Lab',
#  'Type_College Library',
#  'Type_College Math Building',
#  'Type_College Quad',
#  'Type_College Rec Center',
#  'Type_College Residence Hall',
#  'Type_College Science Building',
#  'Type_College Soccer Field',
#  'Type_College Stadium',
#  'Type_College Technology Building',
#  'Type_College Tennis Court',
#  'Type_College Theater',
#  'Type_College Track',
#  'Type_Colombian Restaurant',
#  'Type_Comedy Club',
#  'Type_Comfort Food Restaurant',
#  'Type_Comic Shop',
#  'Type_Community Center',
#  'Type_Community College',
#  'Type_Concert Hall',
#  'Type_Conference',
#  'Type_Conference Room',
#  'Type_Confucian Temple',
#  'Type_Construction & Landscaping',
#  'Type_Convenience Store',
#  'Type_Convention',
#  'Type_Convention Center',
#  'Type_Cooking School',
#  'Type_Corporate Amenity',
#  'Type_Corporate Cafeteria',
#  'Type_Corporate Coffee Shop',
#  'Type_Cosmetics Shop',
#  'Type_Costume Shop',
#  'Type_Country Dance Club',
#  'Type_County',
#  'Type_Courthouse',
#  'Type_Coworking Space',
#  'Type_Credit Union',
#  'Type_Creperie',
#  'Type_Cricket Ground',
#  'Type_Cruise',
#  'Type_Cuban Restaurant',
#  'Type_Cultural Center',
#  'Type_Cupcake Shop',
#  'Type_Currency Exchange',
#  'Type_Cycle Studio',
#  'Type_Czech Restaurant',
#  'Type_Dairy Store',
#  'Type_Dance Studio',
#  'Type_Daycare',
#  'Type_Deli / Bodega',
#  "Type_Dentist's Office",
#  'Type_Department Store',
#  'Type_Design Studio',
#  'Type_Dessert Shop',
#  'Type_Dim Sum Restaurant',
#  'Type_Diner',
#  'Type_Discount Store',
#  'Type_Distillery',
#  'Type_Distribution Center',
#  'Type_Dive Bar',
#  'Type_Dive Spot',
#  "Type_Doctor's Office",
#  'Type_Dog Run',
#  'Type_Doner Restaurant',
#  'Type_Donut Shop',
#  'Type_Dosa Place',
#  'Type_Driving School',
#  'Type_Drugstore',
#  'Type_Dry Cleaner',
#  'Type_Dumpling Restaurant',
#  'Type_Duty-free Shop',
#  'Type_EV Charging Station',
#  'Type_Eastern European Restaurant',
#  'Type_Electronics Store',
#  'Type_Elementary School',
#  'Type_Embassy / Consulate',
#  'Type_Emergency Room',
#  'Type_Empanada Restaurant',
#  'Type_Entertainment Service',
#  'Type_Erotic Museum',
#  'Type_Ethiopian Restaurant',
#  'Type_Event Service',
#  'Type_Event Space',
#  'Type_Exhibit',
#  'Type_Eye Doctor',
#  'Type_Fabric Shop',
#  'Type_Factory',
#  'Type_Fair',
#  'Type_Falafel Restaurant',
#  'Type_Farm',
#  'Type_Farmers Market',
#  'Type_Fast Food Restaurant',
#  'Type_Festival',
#  'Type_Field',
#  'Type_Filipino Restaurant',
#  'Type_Film Studio',
#  'Type_Financial or Legal Service',
#  'Type_Fire Station',
#  'Type_Fireworks Store',
#  'Type_Fish & Chips Shop',
#  'Type_Fish Market',
#  'Type_Fishing Spot',
#  'Type_Fishing Store',
#  'Type_Flea Market',
#  'Type_Flight School',
#  'Type_Floating Market',
#  'Type_Flower Shop',
#  'Type_Fondue Restaurant',
#  'Type_Food',
#  'Type_Food & Drink Shop',
#  'Type_Food Court',
#  'Type_Food Service',
#  'Type_Food Stand',
#  'Type_Food Truck',
#  'Type_Football Stadium',
#  'Type_Forest',
#  'Type_Fountain',
#  'Type_Frame Store',
#  'Type_Fraternity House',
#  'Type_French Restaurant',
#  'Type_Fried Chicken Joint',
#  'Type_Frozen Yogurt Shop',
#  'Type_Fruit & Vegetable Store',
#  'Type_Fujian Restaurant',
#  'Type_Funeral Home',
#  'Type_Furniture / Home Store',
#  'Type_Gaming Cafe',
#  'Type_Garden',
#  'Type_Garden Center',
#  'Type_Gas Station',
#  'Type_Gastropub',
#  'Type_Gay Bar',
#  'Type_General College & University',
#  'Type_General Entertainment',
#  'Type_General Travel',
#  'Type_German Restaurant',
#  'Type_Gift Shop',
#  'Type_Gluten-free Restaurant',
#  'Type_Go Kart Track',
#  'Type_Golf Course',
#  'Type_Golf Driving Range',
#  'Type_Gourmet Shop',
#  'Type_Government Building',
#  'Type_Greek Restaurant',
#  'Type_Grocery Store',
#  'Type_Gun Range',
#  'Type_Gun Shop',
#  'Type_Gym',
#  'Type_Gym / Fitness Center',
#  'Type_Gym Pool',
#  'Type_Gymnastics Gym',
#  'Type_Halal Restaurant',
#  'Type_Harbor / Marina',
#  'Type_Hardware Store',
#  'Type_Hawaiian Restaurant',
#  'Type_Health & Beauty Service',
#  'Type_Health Food Store',
#  'Type_Heliport',
#  'Type_Herbs & Spices Store',
#  'Type_High School',
#  'Type_Himalayan Restaurant',
#  'Type_Hindu Temple',
#  'Type_Historic Site',
#  'Type_History Museum',
#  'Type_Hobby Shop',
#  'Type_Hockey Arena',
#  'Type_Hockey Field',
#  'Type_Hockey Rink',
#  'Type_Home (private)',
#  'Type_Home Service',
#  'Type_Hookah Bar',
#  'Type_Hospital',
#  'Type_Hospital Ward',
#  'Type_Hostel',
#  'Type_Hot Dog Joint',
#  'Type_Hot Spring',
#  'Type_Hotel',
#  'Type_Hotel Bar',
#  'Type_Hotel Pool',
#  'Type_Hotpot Restaurant',
#  'Type_Housing Development',
#  'Type_Hunan Restaurant',
#  'Type_Hunting Supply',
#  'Type_IT Services',
#  'Type_Ice Cream Shop',
#  'Type_Indian Restaurant',
#  'Type_Indie Movie Theater',
#  'Type_Indie Theater',
#  'Type_Indoor Play Area',
#  'Type_Industrial Estate',
#  'Type_Insurance Office',
#  'Type_Internet Cafe',
#  'Type_Intersection',
#  'Type_Irish Pub',
#  'Type_Island',
#  'Type_Israeli Restaurant',
#  'Type_Italian Restaurant',
#  'Type_Japanese Curry Restaurant',
#  'Type_Japanese Restaurant',
#  'Type_Jazz Club',
#  'Type_Jewelry Store',
#  'Type_Jewish Restaurant',
#  'Type_Juice Bar',
#  'Type_Karaoke Bar',
#  'Type_Kebab Restaurant',
#  'Type_Kids Store',
#  'Type_Kingdom Hall',
#  'Type_Kitchen Supply Store',
#  'Type_Knitting Store',
#  'Type_Korean Restaurant',
#  'Type_Kosher Restaurant',
#  'Type_Laboratory',
#  'Type_Lake',
#  'Type_Language School',
#  'Type_Laser Tag',
#  'Type_Latin American Restaurant',
#  'Type_Laundromat',
#  'Type_Laundry Service',
#  'Type_Law School',
#  'Type_Lawyer',
#  'Type_Leather Goods Store',
#  'Type_Lebanese Restaurant',
#  'Type_Library',
#  'Type_Light Rail Station',
#  'Type_Lighthouse',
#  'Type_Lighting Store',
#  'Type_Lingerie Store',
#  'Type_Liquor Store',
#  'Type_Locksmith',
#  'Type_Lounge',
#  'Type_Luggage Store',
#  'Type_Mac & Cheese Joint',
#  'Type_Malay Restaurant',
#  'Type_Marijuana Dispensary',
#  'Type_Market',
#  'Type_Martial Arts Dojo',
#  'Type_Massage Studio',
#  'Type_Maternity Clinic',
#  'Type_Mattress Store',
#  'Type_Medical Center',
#  'Type_Medical Lab',
#  'Type_Medical School',
#  'Type_Medical Supply Store',
#  'Type_Mediterranean Restaurant',
#  'Type_Meeting Room',
#  'Type_Memorial Site',
#  "Type_Men's Store",
#  'Type_Mental Health Office',
#  'Type_Metro Station',
#  'Type_Mexican Restaurant',
#  'Type_Middle Eastern Restaurant',
#  'Type_Middle School',
#  'Type_Military Base',
#  'Type_Mini Golf',
#  'Type_Miscellaneous Shop',
#  'Type_Mobile Phone Shop',
#  'Type_Modern European Restaurant',
#  'Type_Modern Greek Restaurant',
#  'Type_Molecular Gastronomy Restaurant',
#  'Type_Monastery',
#  'Type_Monument / Landmark',
#  'Type_Moroccan Restaurant',
#  'Type_Mosque',
#  'Type_Motel',
#  'Type_Motorcycle Shop',
#  'Type_Motorsports Shop',
#  'Type_Mountain',
#  'Type_Movie Theater',
#  'Type_Moving Target',
#  'Type_Multiplex',
#  'Type_Museum',
#  'Type_Music Festival',
#  'Type_Music School',
#  'Type_Music Store',
#  'Type_Music Venue',
#  'Type_Nail Salon',
#  'Type_National Park',
#  'Type_Nature Preserve',
#  'Type_Neighborhood',
#  'Type_New American Restaurant',
#  'Type_Newsstand',
#  'Type_Night Market',
#  'Type_Nightclub',
#  'Type_Nightlife Spot',
#  'Type_Non-Profit',
#  'Type_Noodle House',
#  'Type_North Indian Restaurant',
#  'Type_Nudist Beach',
#  'Type_Nursery School',
#  'Type_Nutritionist',
#  'Type_Office',
#  'Type_Opera House',
#  'Type_Optical Shop',
#  'Type_Organic Grocery',
#  'Type_Other Event',
#  'Type_Other Great Outdoors',
#  'Type_Other Nightlife',
#  'Type_Other Repair Shop',
#  'Type_Outdoor Event Space',
#  'Type_Outdoor Gym',
#  'Type_Outdoor Sculpture',
#  'Type_Outdoor Supply Store',
#  'Type_Outdoors & Recreation',
#  'Type_Outlet Store',
#  'Type_Paella Restaurant',
#  'Type_Paintball Field',
#  'Type_Pakistani Restaurant',
#  'Type_Palace',
#  'Type_Paper / Office Supplies Store',
#  'Type_Park',
#  'Type_Parking',
#  'Type_Pastry Shop',
#  'Type_Pawn Shop',
#  'Type_Pedestrian Plaza',
#  'Type_Performing Arts Venue',
#  'Type_Perfume Shop',
#  'Type_Persian Restaurant',
#  'Type_Peruvian Restaurant',
#  'Type_Pet Café',
#  'Type_Pet Service',
#  'Type_Pet Store',
#  'Type_Pharmacy',
#  'Type_Photography Lab',
#  'Type_Photography Studio',
#  'Type_Physical Therapist',
#  'Type_Piano Bar',
#  'Type_Pie Shop',
#  'Type_Pier',
#  'Type_Piercing Parlor',
#  'Type_Pilates Studio',
#  'Type_Pizza Place',
#  'Type_Plane',
#  'Type_Planetarium',
#  'Type_Platform',
#  'Type_Playground',
#  'Type_Plaza',
#  'Type_Police Station',
#  'Type_Polish Restaurant',
#  'Type_Pool',
#  'Type_Pool Hall',
#  'Type_Pop-Up Shop',
#  'Type_Port',
#  'Type_Portuguese Restaurant',
#  'Type_Post Office',
#  'Type_Power Plant',
#  'Type_Prayer Room',
#  'Type_Preschool',
#  'Type_Print Shop',
#  'Type_Prison',
#  'Type_Private School',
#  'Type_Professional & Other Places',
#  'Type_Pub',
#  'Type_Public Art',
#  'Type_Public Bathroom',
#  'Type_RV Park',
#  'Type_Racetrack',
#  'Type_Radio Station',
#  'Type_Rafting',
#  'Type_Ramen Restaurant',
#  'Type_Real Estate Office',
#  'Type_Record Shop',
#  'Type_Recording Studio',
#  'Type_Recreation Center',
#  'Type_Recruiting Agency',
#  'Type_Recycling Facility',
#  'Type_Rehab Center',
#  'Type_Religious School',
#  'Type_Rental Car Location',
#  'Type_Rental Service',
#  'Type_Research Station',
#  'Type_Residential Building (Apartment / Condo)',
#  'Type_Resort',
#  'Type_Rest Area',
#  'Type_Restaurant',
#  'Type_River',
#  'Type_Road',
#  'Type_Rock Climbing Spot',
#  'Type_Rock Club',
#  'Type_Roller Rink',
#  'Type_Romanian Restaurant',
#  'Type_Roof Deck',
#  'Type_Rugby Pitch',
#  'Type_Russian Restaurant',
#  'Type_Sake Bar',
#  'Type_Salad Place',
#  'Type_Salon / Barbershop',
#  'Type_Salsa Club',
#  'Type_Salvadoran Restaurant',
#  'Type_Sandwich Place',
#  'Type_Sauna / Steam Room',
#  'Type_Sausage Shop',
#  'Type_Scandinavian Restaurant',
#  'Type_Scenic Lookout',
#  'Type_School',
#  'Type_Science Museum',
#  'Type_Sculpture Garden',
#  'Type_Seafood Restaurant',
#  'Type_Shabu-Shabu Restaurant',
#  'Type_Shanghai Restaurant',
#  'Type_Shipping Store',
#  'Type_Shoe Repair',
#  'Type_Shoe Store',
#  'Type_Shop & Service',
#  'Type_Shopping Mall',
#  'Type_Shopping Plaza',
#  'Type_Shrine',
#  'Type_Skate Park',
#  'Type_Skating Rink',
#  'Type_Ski Area',
#  'Type_Ski Chalet',
#  'Type_Ski Lodge',
#  'Type_Ski Trail',
#  'Type_Smoke Shop',
#  'Type_Smoothie Shop',
#  'Type_Snack Place',
#  'Type_Soccer Field',
#  'Type_Soccer Stadium',
#  'Type_Social Club',
#  'Type_Sorority House',
#  'Type_Soup Place',
#  'Type_South American Restaurant',
#  'Type_South Indian Restaurant',
#  'Type_Southern / Soul Food Restaurant',
#  'Type_Souvenir Shop',
#  'Type_Souvlaki Shop',
#  'Type_Spa',
#  'Type_Spanish Restaurant',
#  'Type_Speakeasy',
#  'Type_Spiritual Center',
#  'Type_Sporting Goods Shop',
#  'Type_Sports Bar',
#  'Type_Sports Club',
#  'Type_Squash Court',
#  'Type_Sri Lankan Restaurant',
#  'Type_Stables',
#  'Type_Stadium',
#  'Type_States & Municipalities',
#  'Type_Stationery Store',
#  'Type_Steakhouse',
#  'Type_Storage Facility',
#  'Type_Street Art',
#  'Type_Street Fair',
#  'Type_Street Food Gathering',
#  'Type_Strip Club',
#  'Type_Student Center',
#  'Type_Summer Camp',
#  'Type_Supermarket',
#  'Type_Supplement Shop',
#  'Type_Surf Spot',
#  'Type_Sushi Restaurant',
#  'Type_Swim School',
#  'Type_Swiss Restaurant',
#  'Type_Synagogue',
#  'Type_Szechuan Restaurant',
#  'Type_TV Station',
#  'Type_Taco Place',
#  'Type_Tailor Shop',
#  'Type_Taiwanese Restaurant',
#  'Type_Takoyaki Place',
#  'Type_Tanning Salon',
#  'Type_Tapas Restaurant',
#  'Type_Tattoo Parlor',
#  'Type_Taxi',
#  'Type_Taxi Stand',
#  'Type_Tea Room',
#  'Type_Tech Startup',
#  'Type_Temple',
#  'Type_Tennis Court',
#  'Type_Tennis Stadium',
#  'Type_Tex-Mex Restaurant',
#  'Type_Thai Restaurant',
#  'Type_Theater',
#  'Type_Theme Park',
#  'Type_Theme Park Ride / Attraction',
#  'Type_Theme Restaurant',
#  'Type_Thrift / Vintage Store',
#  'Type_Tibetan Restaurant',
#  'Type_Tiki Bar',
#  'Type_Toll Plaza',
#  'Type_Tour Provider',
#  'Type_Tourist Information Center',
#  'Type_Town',
#  'Type_Town Hall',
#  'Type_Toy / Game Store',
#  'Type_Track',
#  'Type_Track Stadium',
#  'Type_Trade School',
#  'Type_Trail',
#  'Type_Trailer Park',
#  'Type_Train',
#  'Type_Train Station',
#  'Type_Tram Station',
#  'Type_Transportation Service',
#  'Type_Travel & Transport',
#  'Type_Travel Agency',
#  'Type_Travel Lounge',
#  'Type_Tree',
#  'Type_Tunnel',
#  'Type_Turkish Restaurant',
#  'Type_Udon Restaurant',
#  'Type_Ukrainian Restaurant',
#  'Type_University',
#  'Type_Urgent Care Center',
#  'Type_Used Bookstore',
#  'Type_Vacation Rental',
#  'Type_Vape Store',
#  'Type_Vegetarian / Vegan Restaurant',
#  'Type_Venezuelan Restaurant',
#  'Type_Veterinarian',
#  'Type_Video Game Store',
#  'Type_Video Store',
#  'Type_Vietnamese Restaurant',
#  'Type_Village',
#  'Type_Vineyard',
#  'Type_Volcano',
#  'Type_Volleyball Court',
#  'Type_Voting Booth',
#  'Type_Warehouse',
#  'Type_Warehouse Store',
#  'Type_Waste Facility',
#  'Type_Watch Shop',
#  'Type_Water Park',
#  'Type_Waterfall',
#  'Type_Waterfront',
#  'Type_Wedding Hall',
#  'Type_Weight Loss Center',
#  'Type_Well',
#  'Type_Whisky Bar',
#  'Type_Wine Bar',
#  'Type_Wine Shop',
#  'Type_Winery',
#  'Type_Wings Joint',
#  "Type_Women's Store",
#  'Type_Yoga Studio',
#  'Type_Zoo',
#  'Type_Zoo Exhibit',
#  'Category_Civic',
#  'Category_Consumption',
#  'Category_Education',
#  'Category_Income',
#  'Category_Leisure',
#  'Category_Mobility',
#  'Category_Nutrition',
#  'Category_Personal care',
#  'Category_Social',
#  'Category_Taking care',
#  'Category_Unknown',
#  'Class_',
#  'Class_Necessary',
#  'Class_Optional']

# %%
data_sjoined_sum = data_sjoined.groupby(by='GEOID').sum()
print(data_sjoined_sum.shape,data_sjoined_sum.columns)
data_sjoined_sum_merged = data_sjoined_sum.merge(mergedgpd.loc[:,['GEOID','pct_ch_hinc00_16_0_15', 'geometry']],on='GEOID')
print(data_sjoined_sum_merged.shape,data_sjoined_sum_merged.columns)
data_sjoined_sum_merged = gpd.GeoDataFrame(data_sjoined_sum_merged)
print(data_sjoined_sum_merged.shape,data_sjoined_sum_merged.columns)
# Out:
# (3009, 711) Index(['pct_ch_hinc00_16', 'index_right', 'Rating', 'Checkins', 'Users',
#        'Visits', 'Type_ATM', 'Type_Accessories Store', 'Type_Acupuncturist',
#        'Type_Adult Boutique',
#        ...
#        'Category_Leisure', 'Category_Mobility', 'Category_Nutrition',
#        'Category_Personal care', 'Category_Social', 'Category_Taking care',
#        'Category_Unknown', 'Class_', 'Class_Necessary', 'Class_Optional'],
#       dtype='object', length=711)
# (3009, 714) Index(['GEOID', 'pct_ch_hinc00_16', 'index_right', 'Rating', 'Checkins',
#        'Users', 'Visits', 'Type_ATM', 'Type_Accessories Store',
#        'Type_Acupuncturist',
#        ...
#        'Category_Nutrition', 'Category_Personal care', 'Category_Social',
#        'Category_Taking care', 'Category_Unknown', 'Class_', 'Class_Necessary',
#        'Class_Optional', 'pct_ch_hinc00_16_0_15', 'geometry'],
#       dtype='object', length=714)
# (3009, 714) Index(['GEOID', 'pct_ch_hinc00_16', 'index_right', 'Rating', 'Checkins',
#        'Users', 'Visits', 'Type_ATM', 'Type_Accessories Store',
#        'Type_Acupuncturist',
#        ...
#        'Category_Nutrition', 'Category_Personal care', 'Category_Social',
#        'Category_Taking care', 'Category_Unknown', 'Class_', 'Class_Necessary',
#        'Class_Optional', 'pct_ch_hinc00_16_0_15', 'geometry'],
#       dtype='object', length=714)

# %%
Fq_dummies.shape,data_sjoined_sum.shape, len(data_sjoined_sum_merged.GEOID.unique())
# Out:
# ((106287, 716), (3009, 711), 3009)

# %%
data_sjoined_sum_merged.columns
data_sjoined_sum_merged.drop(columns= 'index_right',inplace=True)

# %%
data_sjoined_sum_merged.columns
# Out:
# Index(['GEOID', 'pct_ch_hinc00_16', 'Rating', 'Checkins', 'Users', 'Visits',
#        'Type_ATM', 'Type_Accessories Store', 'Type_Acupuncturist',
#        'Type_Adult Boutique',
#        ...
#        'Category_Nutrition', 'Category_Personal care', 'Category_Social',
#        'Category_Taking care', 'Category_Unknown', 'Class_', 'Class_Necessary',
#        'Class_Optional', 'pct_ch_hinc00_16_0_15', 'geometry'],
#       dtype='object', length=713)

# %%
data_sjoined_sum_merged.rename(columns={"pct_ch_hinc00_16_0_15": "Typologies"}, inplace = True)

# %%
plt.rcParams['figure.figsize'] = (30, 20)
ax = data_sjoined_sum_merged.plot(column='Typologies', scheme='quantiles', cmap='OrRd')
ax.legend()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/pysal/__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysal` 2.0 prelease candidate. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# data_sjoined_sum_merged.iloc[:,:6]

# %%
# sfig = pd.scatter_matrix(data_sjoined_sum_merged.iloc[:,:6], s=30, figsize=(10, 10), diagonal='kde')

# %%
data_sjoined_sum_merged.columns
# Out:
# Index(['GEOID', 'pct_ch_hinc00_16', 'Rating', 'Checkins', 'Users', 'Visits',
#        'Type_ATM', 'Type_Accessories Store', 'Type_Acupuncturist',
#        'Type_Adult Boutique',
#        ...
#        'Category_Nutrition', 'Category_Personal care', 'Category_Social',
#        'Category_Taking care', 'Category_Unknown', 'Class_', 'Class_Necessary',
#        'Class_Optional', 'Typologies', 'geometry'],
#       dtype='object', length=713)

# %%
data_sjoined_sum_merged.plot(column='Typologies')

# %%
data_sjoined_sum_merged.columns
# Out:
# Index(['GEOID', 'pct_ch_hinc00_16', 'Rating', 'Checkins', 'Users', 'Visits',
#        'Type_ATM', 'Type_Accessories Store', 'Type_Acupuncturist',
#        'Type_Adult Boutique',
#        ...
#        'Category_Nutrition', 'Category_Personal care', 'Category_Social',
#        'Category_Taking care', 'Category_Unknown', 'Class_', 'Class_Necessary',
#        'Class_Optional', 'Typologies', 'geometry'],
#       dtype='object', length=713)

# %% [markdown]
# # Part II. Modeling
# ### Analysis ## FOURSQUARE ONLY

# %%
### Preprocessing Data
### Preprocessing Data
X_foursquare = data_sjoined_sum_merged.drop(['pct_ch_hinc00_16','Typologies','GEOID','geometry'],axis =1).copy()
# X_foursquare = data_sjoined_sum_merged.drop(['Typologies', 'geometry'],axis =1).copy()
y = data_sjoined_sum_merged.Typologies

## change to zeros

# replace with mean/median

# create a new

print(X_foursquare.shape)
# X_foursquare.replace(False,0,inplace=True)
# X_foursquare.replace('FALSE',0,inplace=True)
# X_foursquare.replace('#NULL!',0,inplace=True)
# X_foursquare.replace(nan,0,inplace=True)

X_foursquare.dropna(inplace=True)
print(X_foursquare.shape)
# Out:
# (3009, 709)
# (3009, 709)

# %%
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_foursquare, y, test_size = 0.3, random_state = 1)

# %%
X_foursquare.columns
# Out:
# Index(['Rating', 'Checkins', 'Users', 'Visits', 'Type_ATM',
#        'Type_Accessories Store', 'Type_Acupuncturist', 'Type_Adult Boutique',
#        'Type_Adult Education Center', 'Type_Advertising Agency',
#        ...
#        'Category_Leisure', 'Category_Mobility', 'Category_Nutrition',
#        'Category_Personal care', 'Category_Social', 'Category_Taking care',
#        'Category_Unknown', 'Class_', 'Class_Necessary', 'Class_Optional'],
#       dtype='object', length=709)

# %%
# Normalize
import sklearn.preprocessing as preprocessing
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

models = ['original','scaled','minmaxed']
Xdata_scaled = preprocessing.scale(X_foursquare)
# ydata_scaled = preprocessing.scale(y)

Xdata_minmaxed = min_max_scaler.fit_transform(X_foursquare)
# ydata_minmaxed = min_max_scaler.fit_transform(y)

dictx = {}
dictx['original'] = X_foursquare
dictx['scaled'] = Xdata_scaled
dictx['minmaxed'] = Xdata_minmaxed
                    

# x = dictx[model][0]
# y = dictx[model][1]
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   import sys
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
model = {}
model_f1_scores = {}
model_recall_scores = {}
model_precision_scores = {}

model = {}
modelslist = ['Logit','DT','RF','SVM'] 
for m in models:
    # X_train[m], X_test[m], y_train[m], y_test[m]
    dictx[m]
    model[m] = {}
    model_f1_scores[m] = {}
    model_recall_scores[m] ={}
    model_precision_scores[m] = {}

# %%
from sklearn.model_selection import train_test_split

X_train = {}
X_test = {}
y_train = {}
y_test = {}
for m in models:

    X_train[m], X_test[m], y_train[m], y_test[m] = train_test_split(dictx[m], y, test_size = 0.3, random_state = 1)    
    #x >> dictx[m][0]
    # y =>> dictx[m][1]
    print(X_train[m].shape, X_test[m].shape, y_train[m].shape, y_test[m].shape)
# Out:
# (2106, 709) (903, 709) (2106,) (903,)
# (2106, 709) (903, 709) (2106,) (903,)
# (2106, 709) (903, 709) (2106,) (903,)

# %% [markdown]
# # LR

# %%
## Logistic Reeg
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report
import matplotlib.pylab

for m in models:
#     dictx[m]
#     model[m]
# X_train[m], X_test[m], y_train[m], y_test[m]
    logit_1 = LogisticRegression(C = 10000)
#     print(X_train[m].shape,y_train[m].shape)
    logit_1.fit(X_train[m], y_train[m])
#     print(logit_1.score(X_test[m],y_test[m]))
    model[m]['Logit'] = logit_1.score(X_test[m],y_test[m])
    resultset[m+'_Logit_predicttyp']=logit_1.predict(dictx[m])
    y_pred = logit_1.predict(X_test[m])
    y_true = y_test[m]
    model_f1_scores[m]['Logit'] = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_recall_scores[m]['Logit'] = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_precision_scores[m]['Logit'] = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
#     print(f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
model_f1_scores
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/svm/base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# {'minmaxed': {'DT': 0.3122923588039867,
#   'Logit': 0.34532374100719421,
#   'RF': 0.1271186440677966,
#   'SVM': 0.1271186440677966},
#  'original': {'DT': 0.3122923588039867,
#   'Logit': 0.2729970326409496,
#   'RF': 0.12173913043478261,
#   'SVM': 0.23239436619718309},
#  'scaled': {'DT': 0.3122923588039867,
#   'Logit': 0.34942528735632178,
#   'RF': 0.1176470588235294,
#   'SVM': 0.16260162601626019}}

# %% [markdown]
# # DT

# %%
# This time we'll use max_depth to control the complexity of the tree, still using the same train/test split as above,
# and optimize the parameter value using GridSearchCV.
for m in models:
    #     dictx[m]
    #     model[m]
    param_grid = {'max_depth':range(1,11),'max_leaf_nodes':range(2,11)}
    dt=DecisionTreeClassifier()
    gr=GridSearchCV(dt,param_grid=param_grid,scoring='accuracy')
    ds=gr.fit(X_train[m],y_train[m])
    print (ds.best_params_)

    print(gr.score(X_test[m],y_test[m]))
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 4, 'max_leaf_nodes': 9}
# 0.770764119601
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 4, 'max_leaf_nodes': 9}
# 0.770764119601
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 4, 'max_leaf_nodes': 9}
# 0.770764119601

# %%
seed = 5
# print(y_train.shape, X_train.shape)
for m in models:
    #     dictx[m]
    #     model[m]

    OS = []
    for c in range(5):

        dt=DecisionTreeClassifier()


        dt = DecisionTreeClassifier(max_depth=ds.best_params_['max_depth'],max_leaf_nodes=ds.best_params_['max_leaf_nodes'])
        dt.fit(X_train[m], y_train[m])
        pred=dt.predict_proba(X_test[m])[:,1]
        OS.append(dt.score(X_test[m],y_test[m]))

    print(dt.score(X_test[m],y_test[m]))
    model[m]['DT'] = mean(OS)
    resultset[m+'_DT_predicttyp']=dt.predict(dictx[m])
    y_pred = dt.predict(X_test[m])
    y_true = y_test[m]
    model_f1_scores[m]['DT'] = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_recall_scores[m]['DT'] = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_precision_scores[m]['DT'] = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
#     print(f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
model_f1_scores
# Out:
# 0.770764119601
# 0.770764119601
# 0.770764119601
# {'minmaxed': {'DT': 0.3122923588039867,
#   'Logit': 0.34532374100719421,
#   'RF': 0.14592274678111586,
#   'SVM': 0.14592274678111586},
#  'original': {'DT': 0.3122923588039867,
#   'Logit': 0.2729970326409496,
#   'RF': 0.11255411255411255,
#   'SVM': 0.32470588235294118},
#  'scaled': {'DT': 0.3122923588039867,
#   'Logit': 0.34942528735632178,
#   'RF': 0.14406779661016947,
#   'SVM': 0.20588235294117649}}

# %%
print(m)
list(dt.predict(X_test[m]))
# Out:
# minmaxed
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False]

# %%
resultset=data_sjoined_sum_merged
resultset['predicttyp']=dt.predict(X_foursquare)

# %%
resultset['predicttyp2']=gr.predict(X_foursquare)

# %%
resultset['actualtyp']=data_sjoined_sum_merged.Typologies

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
def featureImportancePlot(rf, labels):
    '''plots feature importance for random forest
    rf: the random forest model fit to the data
    labels: the names of the features
    '''
    
    importances = rf.feature_importances_[:10]
    indices = np.argsort(importances)[::-1]
    std = np.std([tree.feature_importances_ for tree in rf.estimators_],
             axis=0)

    pl.figure()
    pl.title("Feature importances")
    pl.bar(range(indices.shape[0]), rf.feature_importances_[indices],
       color="SteelBlue", yerr=std[indices], align="center")
    pl.xticks(range(indices.shape[0]), np.array(labels)[indices], rotation=90)
    pl.xlim([-1, indices.shape[0]])
    pl.show()

# %%
for m in models:
    #     dictx[m]
    print(m)
    param_grid = {'max_depth':range(1,11),'n_estimators':range(1,11),'max_leaf_nodes':range(2,11)}
    rf=RandomForestClassifier()
    gr=GridSearchCV(rf,param_grid=param_grid,scoring='accuracy')
    rs=gr.fit(X_train[m],y_train[m])
    print (rs.best_params_)
    print(gr.score(X_test[m],y_test[m]))
    OS = []
    print("i am here")
    for c in range(5):
        rf=RandomForestClassifier()
        rf = RandomForestClassifier(max_depth=rs.best_params_['max_depth'],max_leaf_nodes=rs.best_params_['max_leaf_nodes'])
        rf.fit(X_train[m], y_train[m])
        pred=rf.predict_proba(X_test[m])[:,1]
        OS.append(rf.score(X_test[m],y_test[m]))
    print(rf.score(X_test[m],y_test[m]))
    model[m]['RF'] = mean(OS)
    featureImportancePlot(rf, X_foursquare.columns)
    resultset[m+'_RF_predicttyp']=rf.predict(dictx[m])
    y_pred = rf.predict(X_test[m])
    y_true = y_test[m]
    model_f1_scores[m]['RF'] = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_recall_scores[m]['RF'] = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_precision_scores[m]['RF'] = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
#     print(f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
#     print(precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None))
model_f1_scores
# Out:
# original
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 10, 'n_estimators': 4, 'max_leaf_nodes': 8}
# 0.771871539313
# i am here
# 0.776301218162
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# scaled
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 6, 'n_estimators': 8, 'max_leaf_nodes': 7}
# 0.771871539313
# i am here
# 0.767441860465
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# minmaxed
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'max_depth': 8, 'n_estimators': 7, 'max_leaf_nodes': 10}
# 0.778516057586
# i am here
# 0.771871539313
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# {'minmaxed': {'DT': 0.3122923588039867,
#   'Logit': 0.34532374100719421,
#   'RF': 0.1271186440677966,
#   'SVM': 0.14592274678111586},
#  'original': {'DT': 0.3122923588039867,
#   'Logit': 0.2729970326409496,
#   'RF': 0.12173913043478261,
#   'SVM': 0.32470588235294118},
#  'scaled': {'DT': 0.3122923588039867,
#   'Logit': 0.34942528735632178,
#   'RF': 0.1176470588235294,
#   'SVM': 0.20588235294117649}}

# %% [markdown]
# #### Note that the features have changed considerably with the updated binary typology-- users and checkins were the most important features initially.

# %% [markdown]
# # SVM

# %%
from sklearn.model_selection import GridSearchCV

# When C is very small, we are willing to tolerate more mistakes. If C is very big, this
# means we hardly tolerate any mistakes. So, we cannot choose a very large C if our data is not
# really separable. Let's however choose from a broad range of reasonable options.
# param_grid = {'kernel':['linear'],'C':[np.exp(i) for i in np.linspace(-10,10,10)]}
for m in models:
    OS = []
    #     dictx[m]
        #     model[m]
    rr = svm.SVC(gamma='auto')
    rr.fit(X_train[m], y_train[m])
    correct=1.0*(rr.predict(X_test[m])==np.asarray(y_test[m])).sum()/len(y_test[m])
    print(correct)
    print(rr.score(X_test[m],y_test[m]))
    OS.append(correct)
    resultset[m+'_SVM_predicttyp']=rr.predict(dictx[m])
    model[m]['SVM'] = mean(OS)
    y_pred = rf.predict(X_test[m])
    y_true = y_test[m]
    model_f1_scores[m]['SVM'] = f1_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_recall_scores[m]['SVM'] = recall_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
    model_precision_scores[m]['SVM'] = precision_score(y_true, y_pred, labels=None, pos_label=1, average='binary', sample_weight=None)
model
# Out:
# 0.763012181617
# 0.763012181617
# 0.764119601329
# 0.764119601329
# 0.765227021041
# 0.765227021041
# {'minmaxed': {'DT': 0.77076411960132896,
#   'Logit': 0.69767441860465118,
#   'RF': 0.7725359911406422,
#   'SVM': 0.76522702104097451},
#  'original': {'DT': 0.77076411960132896,
#   'Logit': 0.72868217054263562,
#   'RF': 0.77342192691029898,
#   'SVM': 0.76301218161683282},
#  'scaled': {'DT': 0.77076411960132896,
#   'Logit': 0.6866002214839424,
#   'RF': 0.77098560354374313,
#   'SVM': 0.76411960132890366}}

# %%
for m in models:
    print(m)
    for i in modelslist:
        print(i)
        print(model[m][i])
    print('-----------------------------------------------------')
# Out:
# original
# Logit
# 0.728682170543
# DT
# 0.770764119601
# RF
# 0.77342192691
# SVM
# 0.763012181617
# -----------------------------------------------------
# scaled
# Logit
# 0.686600221484
# DT
# 0.770764119601
# RF
# 0.770985603544
# SVM
# 0.764119601329
# -----------------------------------------------------
# minmaxed
# Logit
# 0.697674418605
# DT
# 0.770764119601
# RF
# 0.772535991141
# SVM
# 0.765227021041
# -----------------------------------------------------

# %%
for m in models:
    print(m)
    for i in modelslist:
        print(i)
        print(model_f1_scores[m][i])
    print('-----------------------------------------------------')
    print(model_f1_scores[m].keys(), model_f1_scores[m].values())
model_f1_scores.keys(), model_f1_scores.values()
# Out:
# original
# Logit
# 0.272997032641
# DT
# 0.312292358804
# RF
# 0.121739130435
# SVM
# 0.232394366197
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.23239436619718309, 0.2729970326409496, 0.12173913043478261, 0.3122923588039867])
# scaled
# Logit
# 0.349425287356
# DT
# 0.312292358804
# RF
# 0.117647058824
# SVM
# 0.162601626016
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.16260162601626019, 0.34942528735632178, 0.1176470588235294, 0.3122923588039867])
# minmaxed
# Logit
# 0.345323741007
# DT
# 0.312292358804
# RF
# 0.127118644068
# SVM
# 0.127118644068
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.1271186440677966, 0.34532374100719421, 0.1271186440677966, 0.3122923588039867])
# (dict_keys(['original', 'scaled', 'minmaxed']),
#  dict_values([{'SVM': 0.23239436619718309, 'Logit': 0.2729970326409496, 'RF': 0.12173913043478261, 'DT': 0.3122923588039867}, {'SVM': 0.16260162601626019, 'Logit': 0.34942528735632178, 'RF': 0.1176470588235294, 'DT': 0.3122923588039867}, {'SVM': 0.1271186440677966, 'Logit': 0.34532374100719421, 'RF': 0.1271186440677966, 'DT': 0.3122923588039867}]))

# %%
for m in models:
    print(m)
    for i in modelslist:
        print(i)
        print(model_recall_scores[m][i])
    print('-----------------------------------------------------')
    print(model_recall_scores[m].keys(), model_recall_scores[m].values())
model_recall_scores.keys(), model_recall_scores.values()
# Out:
# original
# Logit
# 0.216981132075
# DT
# 0.221698113208
# RF
# 0.0660377358491
# SVM
# 0.155660377358
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.15566037735849056, 0.21698113207547171, 0.066037735849056603, 0.22169811320754718])
# scaled
# Logit
# 0.358490566038
# DT
# 0.221698113208
# RF
# 0.0660377358491
# SVM
# 0.0943396226415
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.094339622641509441, 0.35849056603773582, 0.066037735849056603, 0.22169811320754718])
# minmaxed
# Logit
# 0.339622641509
# DT
# 0.221698113208
# RF
# 0.0707547169811
# SVM
# 0.0707547169811
# -----------------------------------------------------
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.070754716981132074, 0.33962264150943394, 0.070754716981132074, 0.22169811320754718])
# (dict_keys(['original', 'scaled', 'minmaxed']),
#  dict_values([{'SVM': 0.15566037735849056, 'Logit': 0.21698113207547171, 'RF': 0.066037735849056603, 'DT': 0.22169811320754718}, {'SVM': 0.094339622641509441, 'Logit': 0.35849056603773582, 'RF': 0.066037735849056603, 'DT': 0.22169811320754718}, {'SVM': 0.070754716981132074, 'Logit': 0.33962264150943394, 'RF': 0.070754716981132074, 'DT': 0.22169811320754718}]))

# %%
for m in models:
    print(m)
    for i in modelslist:
        print(i)
        print(model_precision_scores[m][i])
    print(model_precision_scores[m].keys(), model_precision_scores[m].values())
    print('-----------------------------------------------------')
# Out:
# original
# Logit
# 0.368
# DT
# 0.52808988764
# RF
# 0.777777777778
# SVM
# 0.458333333333
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.45833333333333331, 0.36799999999999999, 0.77777777777777779, 0.5280898876404494])
# -----------------------------------------------------
# scaled
# Logit
# 0.340807174888
# DT
# 0.52808988764
# RF
# 0.538461538462
# SVM
# 0.588235294118
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.58823529411764708, 0.34080717488789236, 0.53846153846153844, 0.5280898876404494])
# -----------------------------------------------------
# minmaxed
# Logit
# 0.351219512195
# DT
# 0.52808988764
# RF
# 0.625
# SVM
# 0.625
# dict_keys(['SVM', 'Logit', 'RF', 'DT']) dict_values([0.625, 0.35121951219512193, 0.625, 0.5280898876404494])
# -----------------------------------------------------

# %% [markdown]
# - You can refer to https://github.com/mv1742/updny_2

# %% [markdown]
# ## Results Analysis

# %%
print(m)
resultset.columns
# Out:
# minmaxed
# Index(['GEOID', 'pct_ch_hinc00_16', 'Rating', 'Checkins', 'Users', 'Visits',
#        'Type_ATM', 'Type_Accessories Store', 'Type_Acupuncturist',
#        'Type_Adult Boutique',
#        ...
#        'minmaxed_logitpredicttyp', 'original_DT_predicttyp',
#        'scaled_DT_predicttyp', 'minmaxed_DT_predicttyp',
#        'original_RF_predicttyp', 'scaled_RF_predicttyp',
#        'minmaxed_RF_predicttyp', 'original_SVM_predicttyp',
#        'scaled_SVM_predicttyp', 'minmaxed_SVM_predicttyp'],
#       dtype='object', length=729)

# %% [markdown]
# The plots below show the number of positive (gentrifying, 1) and negative (not-gentrifying, 0) typologies based on the actual typology labels and the predicted labels from each model.

# %%
resultset['actualtyp'].value_counts().plot(kind='bar', figsize=(5,2))
resultset['actualtyp'].value_counts()
# Out:
# False    2319
# True      690
# Name: actualtyp, dtype: int64

# %%
for m in models:
    for i in modelslist:
        resultset[m+'_'+i+'_predicttyp'].value_counts().plot(kind='bar',figsize=(5,2))
        plt.show()
        print(resultset[m+'_'+i+'_predicttyp'].value_counts())
# Out:
# False    2619
# True      390
# Name: original_Logit_predicttyp, dtype: int64
# False    2696
# True      313
# Name: original_DT_predicttyp, dtype: int64
# False    2946
# True       63
# Name: original_RF_predicttyp, dtype: int64
# False    2555
# True      454
# Name: original_SVM_predicttyp, dtype: int64
# False    2407
# True      602
# Name: scaled_Logit_predicttyp, dtype: int64
# False    2696
# True      313
# Name: scaled_DT_predicttyp, dtype: int64
# False    2921
# True       88
# Name: scaled_RF_predicttyp, dtype: int64
# False    2823
# True      186
# Name: scaled_SVM_predicttyp, dtype: int64
# False    2431
# True      578
# Name: minmaxed_Logit_predicttyp, dtype: int64
# False    2696
# True      313
# Name: minmaxed_DT_predicttyp, dtype: int64
# False    2918
# True       91
# Name: minmaxed_RF_predicttyp, dtype: int64
# False    3009
# Name: minmaxed_SVM_predicttyp, dtype: int64

# %%
from sklearn import metrics
metrics.confusion_matrix(resultset.actualtyp, resultset.original_RF_predicttyp)
# Out:
# array([[2311,    8],
#        [ 635,   55]])

# %%
def perf_measure(y_actual, y_hat):
    TP = 0
    FP = 0
    TN = 0
    FN = 0

    for i in range(len(y_hat)): 
        if y_actual[i]==y_hat[i]==1:
           TP += 1
        if y_hat[i]==1 and y_actual[i]!=y_hat[i]:
           FP += 1
        if y_actual[i]==y_hat[i]==0:
           TN += 1
        if y_hat[i]==0 and y_actual[i]!=y_hat[i]:
           FN += 1

    return(TP, FP, TN, FN)

# %%
perf_measure(resultset.actualtyp, resultset.scaled_Logit_predicttyp)
# Out:
# (406, 196, 2123, 284)

# %% [markdown]
# Below you can see that logit produces 30 positive results (19 true and 11 false), while random forest produces only 1 positive (it is true).

# %%
perf_measure(resultset.actualtyp, resultset.original_DT_predicttyp)
# Out:
# (194, 119, 2200, 496)

# %%
perf_measure(resultset.actualtyp, resultset.scaled_Logit_predicttyp)
# Out:
# (406, 196, 2123, 284)

# %%
resultsfull=data_sjoined_sum_merged.merge(resultset[["scaled_Logit_predicttyp"]], right_index=True, left_index=True)

# %%
resultsfull.head()

# %%
def set_resulttyp(row):
    if row["actualtyp"] == 0:
        if row["scaled_Logit_predicttyp"] == 0:
            return "TN"
        elif row["scaled_Logit_predicttyp"] == 1: 
            return "FP" 
    elif row["actualtyp"] == 1:
        if row["scaled_Logit_predicttyp"] == 1:
            return "TP"
        elif  row["scaled_Logit_predicttyp"] == 0:
            return "FN"

#df = df.assign(color=df.apply(set_color, axis=1))

# %%
resultsfinal=resultsfull.assign(logitresulttyp=resultset.apply(set_resulttyp, axis=1))

# %%
f, ax = plt.subplots(figsize=(16,16))
resultsfinal.plot(column='logitresulttyp', ax=ax, legend=True)

# %% [markdown]
# The only positive results for the logit model (whether true or false positive) fell in the NYC and Jersey City areas-- no outer borough or other NJ/CT/NY tracts were picked up.
